# %% [markdown]
# # 信用卡欺诈检测 — 金额感知损失函数与迁移实验
#
# 本 notebook 独立验证金额感知损失函数，不修改主 notebook 的既有结果。
#
# ## 阅读方式
#
# - **§0–§4**：公式、数据协议、复用函数、权重实现与业务指标。
# - **§5**：第一阶段，在 BASE 特征上依次执行实验 0、1、2、3。
# - **§6**：从阶段一结果中输出 Pareto 前沿并选择暂定参数。
# - **§7**：第二阶段，执行“BASE / §7–8 胜者 × 标准 / 新损失”的 2×2 迁移实验。
# - 所有输出写入 `src/output/amount_aware_loss/`，不覆盖 `final_report/`。
#
# 完整跑批计算量较大，默认关闭。先运行所有 prep cell，再将顶部的
# `RUN_STAGE1` 或 `RUN_STAGE2` 改为 `True`。每组 OOF 会单独缓存，中断后可继续。

# %%
# §0 导入依赖
# %matplotlib inline
from pathlib import Path
import hashlib
import json
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import average_precision_score, confusion_matrix, precision_recall_curve
import lightgbm as lgb
import xgboost as xgb
import optuna
from purgedcv import WalkForwardSplit
from purgedcv.diagnostics import assert_no_temporal_leakage
from IPython.display import display

pd.set_option('display.max_columns', 30)
pd.set_option('display.width', 150)
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'Heiti TC', 'PingFang SC', 'SimHei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 0. V2 研究设计：先修比较协议，再扩大搜索
#
# V1 的 `matchedFP` 只在 calibration 匹配 FP，迁移到 evaluation 后曾出现 7 个预算对应 47,664 个 FP，不能用于选参。V2 改用固定告警量 **Top-K**：所有候选在同一数据段只比较风险分数最高的 K 笔，因此工作量严格相同，不依赖概率刻度能否跨时间迁移。
#
# 参数搜索只使用 OOF calibration 段的 `AmountRecall@K`、`MicroRecall@K` 与 AUC-PR；evaluation 段只用于最终候选验收。
#
# 训练协议也统一：neutral 和金额感知候选都只给 fit 子集传 `sample_weight`，早停集统一使用未加权 logloss。实验 0 仍保留原 notebook 的内置 balanced 模型作为锚点，并检查 neutral 是否足够接近。
#
# 执行顺序：粗网格实验 0–3 → 局部精细网格 → Optuna 多目标搜索 → 合并 calibration Pareto 候选 → 第二阶段 2×2 迁移。

# %%
# §0 V2 参数与路径
RUN_COARSE_GRID = True
RUN_FINE_GRID = True
RUN_OPTUNA = True
RUN_STAGE2 = True
# RUN_STABILITY = os.environ.get('RUN_STABILITY', '0') == '1'
RUN_STABILITY = True
FORCE_RERUN = True
OPTUNA_N_TRIALS = 30
PARITY_AUC_TOL = 0.01
STABILITY_SEEDS = [42, 52, 62, 72, 82]
BOOTSTRAP_N = 2000
BOOTSTRAP_RANDOM_STATE = 20260707

MODELS = ['LightGBM', 'XGBoost']
BETA_GRID = [0.25, 0.5, 1.0, 2.0, 4.0]
ETA_GRID = [0.25, 0.5, 1.0, 2.0]
KAPPA_GRID = [0.5, 0.75, 1.0, 1.25, 1.5]

CV_N_SPLITS = 5
CV_RANDOM_STATE = 42
CV_EMBARGO = pd.Timedelta(hours=2)
CV_PURGE_HORIZON = pd.Timedelta(0)
EARLY_STOPPING_ROUNDS = 50
MAX_BOOST_ROUNDS = 1500
ES_FRAC = 0.20
ES_MIN_FRAUD = 5
ES_MAX_FRAC = 0.35
OOF_CAL_FRAC = 0.25
OOF_CAL_MIN_FRAUD = 50
OOF_CAL_MAX_FRAC = 0.40

ABLATION_WINNER_LABEL = 'IF+Ed[log1p+one_euro+micro+bands]+A_top2(V14+V4)'


def find_project_root(start=None):
    start = Path.cwd().resolve() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / 'input' / 'creditcard.csv').exists():
            return candidate
    raise FileNotFoundError('无法找到 input/creditcard.csv，请从项目内启动 notebook')


PROJECT_ROOT = find_project_root()
SRC_DIR = PROJECT_ROOT / 'src'
DATA_PATH = PROJECT_ROOT / 'input' / 'creditcard.csv'
FINAL_REPORT_DIR = SRC_DIR / 'output' / 'final_report'
OUT_AMOUNT_LOSS = SRC_DIR / 'output' / 'amount_aware_loss_v2'
OUT_COARSE = OUT_AMOUNT_LOSS / '01_coarse_grid'
OUT_FINE = OUT_AMOUNT_LOSS / '02_fine_grid'
OUT_OPTUNA = OUT_AMOUNT_LOSS / '03_optuna'
OUT_STAGE2 = OUT_AMOUNT_LOSS / '04_stage2_transfer'
OUT_STABILITY = OUT_AMOUNT_LOSS / '05_stability'
STABILITY_PRED_DIR = OUT_STABILITY / 'predictions'
OOF_CACHE_DIR = OUT_AMOUNT_LOSS / 'oof_cache'
for _d in (OUT_AMOUNT_LOSS, OUT_COARSE, OUT_FINE, OUT_OPTUNA, OUT_STAGE2,
           OUT_STABILITY, STABILITY_PRED_DIR, OOF_CACHE_DIR):
    _d.mkdir(parents=True, exist_ok=True)

print('PROJECT_ROOT:', PROJECT_ROOT)
print('V2 独立输出目录:', OUT_AMOUNT_LOSS)
# Out:
# PROJECT_ROOT: /Users/jingyuhe/Desktop/credit-fraud-dealing-with-imbalanced-datasets
# V2 独立输出目录: /Users/jingyuhe/Desktop/credit-fraud-dealing-with-imbalanced-datasets/src/output/amount_aware_loss_v2

# %% [markdown]
# ## 1. 统一损失函数：基础欺诈价值 + 金额价值 + 卡测试保护
#
# 对每个训练折的 **fit 子集**，定义类别不平衡比：
#
# $$r=\frac{N_0}{N_1}$$
#
# 金额函数使用对数、欺诈样本 95% 分位截尾，并缩放到 $[0,1]$：
#
# $$g(A_i)=\frac{\min[\log(1+A_i),q_{95}^{+}]}{q_{95}^{+}}$$
#
# 小额卡测试指示变量：
#
# $$h(A_i)=\mathbb I(A_i\le1)$$
#
# 欺诈内部业务权重：
#
# $$u_i=1+\beta g(A_i)+\eta h(A_i)$$
#
# 其中基础项 1 保证零金额和小额欺诈不会被忽略；$\beta$ 只控制大额欺诈倾向；$\eta$ 只控制小额卡测试保护。为了避免改变 $\beta,\eta$ 时连带改变整个正类总权重，使用 fit 子集正类均值归一化：
#
# $$\bar u_+=\frac1{N_1}\sum_{j:y_j=1}u_j$$
#
# 最终样本权重为：
#
# $$w_i=\begin{cases}1,&y_i=0\\
# \kappa r\dfrac{u_i}{\bar u_+},&y_i=1\end{cases}$$
#
# 损失函数是加权二元交叉熵：
#
# $$\boxed{\mathcal L=-\frac1n\sum_iw_i[y_i\log p_i+(1-y_i)\log(1-p_i)]}$$
#
# - $r$：处理类别不平衡，对应原模型的 balanced 权重。
# - $\kappa$：调整整个欺诈类相对于正常类的重要性。
# - $\beta$：在欺诈类内部向大额交易重新分配权重。
# - $\eta$：在欺诈类内部向 `Amount<=1` 的卡测试交易重新分配权重。
# - $\bar u_+$：让 $\beta,\eta$ 只改变正类内部结构，不偷偷放大正类总权重。
#
# **防泄漏约束：** $r,q_{95}^{+},\bar u_+$ 只能在每折 fit 子集计算；早停集和验证折只能使用已有状态 transform。
#
# 失败原因：虽然损失函数用了银行的惯例做法，但银行不会只靠 Amount 区分欺诈。由于所有特征业务含义已被 PCA 脱敏破坏，哪怕照搬银行的方法也得不到好的效果。

# %%
# §1 prep：金额感知权重
def fit_weight_state(amount, y, beta, eta, kappa, clip_quantile=0.95, micro_max=1.0):
    amount = np.asarray(amount, dtype=float)
    y = np.asarray(y, dtype=int)
    if len(amount) != len(y):
        raise ValueError('amount 与 y 长度不一致')
    if beta < 0 or eta < 0 or kappa <= 0:
        raise ValueError('要求 beta>=0、eta>=0、kappa>0')
    pos = y == 1
    n_pos, n_neg = int(pos.sum()), int((~pos).sum())
    if n_pos == 0 or n_neg == 0:
        raise ValueError('fit 子集必须同时包含正常与欺诈样本')

    log_amount = np.log1p(np.clip(amount, 0.0, None))
    q95_pos = float(np.quantile(log_amount[pos], clip_quantile))
    q95_pos = max(q95_pos, 1e-12)
    g = np.clip(log_amount / q95_pos, 0.0, 1.0)
    h = (amount <= micro_max).astype(float)
    u = 1.0 + float(beta) * g + float(eta) * h
    u_bar_pos = float(u[pos].mean())
    return {
        'beta': float(beta), 'eta': float(eta), 'kappa': float(kappa),
        'clip_quantile': float(clip_quantile), 'micro_max': float(micro_max),
        'q95_pos': q95_pos, 'u_bar_pos': u_bar_pos,
        'class_ratio': float(n_neg / n_pos),
        'n_pos_fit': n_pos, 'n_neg_fit': n_neg,
    }


def transform_business_weight(amount, y, state):
    amount = np.asarray(amount, dtype=float)
    y = np.asarray(y, dtype=int)
    log_amount = np.log1p(np.clip(amount, 0.0, None))
    g = np.clip(log_amount / state['q95_pos'], 0.0, 1.0)
    h = (amount <= state['micro_max']).astype(float)
    u = 1.0 + state['beta'] * g + state['eta'] * h
    weight = np.ones(len(y), dtype=float)
    pos = y == 1
    weight[pos] = (
        state['kappa'] * state['class_ratio']
        * u[pos] / state['u_bar_pos']
    )
    if not np.isfinite(weight).all() or (weight <= 0).any():
        raise ValueError('出现非有限或非正样本权重')
    return weight

# %%
# §1 exec：权重不变量自检（不训练模型）
_amount = np.array([0.0, 1.0, 10.0, 1000.0, 20.0, 30.0])
_y = np.array([1, 1, 1, 1, 0, 0])

_neutral = fit_weight_state(_amount, _y, beta=0, eta=0, kappa=1)
_w0 = transform_business_weight(_amount, _y, _neutral)
assert np.allclose(_w0[_y == 0], 1.0)
assert np.allclose(_w0[_y == 1], _neutral['class_ratio'])

_amount_state = fit_weight_state(_amount, _y, beta=2, eta=0, kappa=1)
_wa = transform_business_weight(_amount, _y, _amount_state)
assert _wa[3] > _wa[2]  # 大额欺诈比中额欺诈权重高

_micro_state = fit_weight_state(_amount, _y, beta=0, eta=2, kappa=1)
_wm = transform_business_weight(_amount, _y, _micro_state)
assert _wm[0] > _wm[2] and _wm[1] > _wm[2]
print('权重公式自检通过')
display(pd.DataFrame({'Amount': _amount, 'Class': _y, 'neutral': _w0, 'amount_weighted': _wa, 'micro_weighted': _wm}))
# Out:
# 权重公式自检通过
#    Amount  Class  neutral  amount_weighted  micro_weighted
# 0     0.0      1      0.5         0.286042            0.75
# 1     1.0      1      0.5         0.349671            0.75
# 2    10.0      1      0.5         0.506160            0.25
# 3  1000.0      1      0.5         0.858127            0.25
# 4    20.0      0      1.0         1.000000            1.00
# 5    30.0      0      1.0         1.000000            1.00

# %% [markdown]
# ## 2. 数据与 §7/8 胜者解析
#
# 为保证 2×2 实验完全对齐，BASE 与胜者都从主 notebook 已保存的 `df_features.pkl` 读取。这里只读取主报告结果，不写回 `final_report/`。
#
# 注意：`runtime_state.json` 中的 `WINNER_FEATURES` 可能已被后续 FE8 实验更新，因此本 notebook 不直接使用它；而是按 §7/8 固定标签从 `ablation_combo_specs.csv` 精确解析 8 个额外列。

# %%
# §2 prep：数据与特征组
def resolve_ablation_extra(label):
    path = FINAL_REPORT_DIR / '07_ablation' / 'ablation_combo_specs.csv'
    if not path.is_file():
        raise FileNotFoundError(f'缺少 §7 输出: {path}')
    specs = pd.read_csv(path)
    row = specs[specs['label'].astype(str).str.strip() == label]
    if row.empty:
        raise KeyError(f'未找到 §7/8 胜者: {label}')
    return [c.strip() for c in str(row.iloc[0]['extra_cols']).split('|') if c.strip()]


state = json.loads((FINAL_REPORT_DIR / 'runtime_state.json').read_text(encoding='utf-8'))
BASE_FEATURES = list(state['BASE_FEATURES'])
WINNER_EXTRA = resolve_ablation_extra(ABLATION_WINNER_LABEL)
WINNER_FEATURES = BASE_FEATURES + WINNER_EXTRA

feature_path = FINAL_REPORT_DIR / 'df_features.pkl'
if not feature_path.is_file():
    raise FileNotFoundError(f'请先运行主 notebook 到 §7: {feature_path}')
df_all = pd.read_pickle(feature_path).sort_values('Time', kind='mergesort').reset_index(drop=True)
missing = [c for c in WINNER_FEATURES + ['Class', 'Amount', 'Time'] if c not in df_all.columns]
if missing:
    raise KeyError(f'df_features 缺列: {missing}')

print('样本数:', len(df_all), '| 欺诈数:', int(df_all['Class'].sum()))
print('BASE:', len(BASE_FEATURES), '列')
print('§7/8 胜者:', ABLATION_WINNER_LABEL)
print('额外列:', WINNER_EXTRA)
# Out:
# 样本数: 284807 | 欺诈数: 492
# BASE: 30 列
# §7/8 胜者: IF+Ed[log1p+one_euro+micro+bands]+A_top2(V14+V4)
# 额外列: ['if_oof_score', 'log1p_amount', 'is_one_euro', 'is_micro_testing', 'is_amount_1_30', 'is_amount_75_110', 'one_euro_V14', 'one_euro_V4']

# %% [markdown]
# ## 3. 统一训练与早停协议
#
# - CV、embargo 与时间早停切分沿用主 notebook。
# - `builtin` 只用于复现原始 baseline。
# - `neutral` 与所有金额感知候选统一关闭模型内置类别权重，类别不平衡和业务权重全部由 fit 子集的 `sample_weight` 表达。
# - 早停集不再传样本权重，所有方案统一用未加权 logloss 选择迭代轮数，避免“改变损失”同时改变早停评价口径。

# %%
# §3 prep：时间 CV
def build_cv_timestamps(data):
    t = pd.to_timedelta(data['Time'].astype(float), unit='s')
    return t.copy(), t.copy()


def iter_purged_cv_folds(data, n_splits=CV_N_SPLITS):
    n = len(data)
    pred, evalu = build_cv_timestamps(data)
    test_size = max(1, n // (n_splits + 1))
    cv = WalkForwardSplit(
        n_splits=n_splits, test_size=test_size, window='expanding',
        prediction_times=pred, evaluation_times=evalu,
        purge_horizon=CV_PURGE_HORIZON, embargo=CV_EMBARGO,
    )
    for tr_idx, va_idx in cv.split(np.arange(n)):
        assert_no_temporal_leakage(
            tr_idx, va_idx, prediction_times=pred, evaluation_times=evalu,
            purge_horizon=CV_PURGE_HORIZON,
        )
        yield np.asarray(tr_idx), np.asarray(va_idx)


def temporal_es_masks(y, es_frac=ES_FRAC, min_fraud_es=ES_MIN_FRAUD, max_frac=ES_MAX_FRAC):
    y = np.asarray(y, dtype=int)
    fraud_idx = np.flatnonzero(y == 1)
    norm_idx = np.flatnonzero(y == 0)
    if len(fraud_idx) < 2:
        n_es = max(1, min(len(y) - 1, int(len(y) * es_frac)))
        es = np.zeros(len(y), dtype=bool)
        es[-n_es:] = True
        return ~es, es
    frac = es_frac
    while frac <= max_frac + 1e-9:
        n_fraud_es = min(max(min_fraud_es, int(len(fraud_idx) * frac)), len(fraud_idx) - 1)
        n_norm_es = min(max(1, int(len(norm_idx) * frac)), len(norm_idx) - 1)
        es = np.zeros(len(y), dtype=bool)
        es[fraud_idx[-n_fraud_es:]] = True
        es[norm_idx[-n_norm_es:]] = True
        if int(y[es].sum()) >= min(min_fraud_es, len(fraud_idx) - 1):
            return ~es, es
        frac += 0.05
    raise ValueError('无法构造含足够欺诈样本的时间早停集')

# %%
# §3 prep：模型工厂与统一早停
def make_classifier(model_name, y_train, random_state, weight_scheme='balanced'):
    y_train = np.asarray(y_train, dtype=int)
    spw = float((y_train == 0).sum() / max((y_train == 1).sum(), 1))
    if model_name == 'LightGBM':
        params = dict(
            n_estimators=MAX_BOOST_ROUNDS, learning_rate=0.05, max_depth=6,
            num_leaves=31, min_child_samples=20, subsample=0.8, colsample_bytree=0.8,
            reg_alpha=0.1, reg_lambda=0.1, random_state=random_state, verbose=-1, n_jobs=-1,
        )
        if weight_scheme == 'balanced':
            params['class_weight'] = 'balanced'
        elif weight_scheme != 'no_weight':
            raise ValueError(weight_scheme)
        return lgb.LGBMClassifier(**params)
    if weight_scheme not in ('balanced', 'no_weight'):
        raise ValueError(weight_scheme)
    return xgb.XGBClassifier(
        n_estimators=MAX_BOOST_ROUNDS, learning_rate=0.05, max_depth=6,
        min_child_weight=1, subsample=0.8, colsample_bytree=0.8,
        reg_alpha=0.1, reg_lambda=1.0, early_stopping_rounds=EARLY_STOPPING_ROUNDS,
        random_state=random_state, eval_metric='logloss', verbosity=0, n_jobs=-1,
        scale_pos_weight=spw if weight_scheme == 'balanced' else 1.0,
    )


def fit_classifier(clf, model_name, X_fit, y_fit, X_es, y_es,
                   sample_weight=None, eval_sample_weight=None):
    # eval_sample_weight 参数仅保留 API 兼容；V2 明确不用于早停。
    kwargs = {'eval_set': [(X_es, y_es)]}
    if sample_weight is not None:
        kwargs['sample_weight'] = sample_weight
    if model_name == 'LightGBM':
        kwargs['eval_metric'] = 'binary_logloss'
        kwargs['callbacks'] = [lgb.early_stopping(EARLY_STOPPING_ROUNDS, verbose=False)]
    else:
        kwargs['verbose'] = False
    clf.fit(X_fit, y_fit, **kwargs)
    return clf

# %%
# §3 prep：标准、neutral 与金额感知 OOF
def cross_val_builtin_oof(model_name, data, feature_cols, random_state=CV_RANDOM_STATE):
    X, y = data[feature_cols], data['Class'].astype(int)
    oof = np.full(len(data), np.nan, dtype=float)
    fold_ap = []
    for fold, (tr, va) in enumerate(iter_purged_cv_folds(data), start=1):
        fit_mask, es_mask = temporal_es_masks(y.iloc[tr])
        fit_idx, es_idx = tr[fit_mask], tr[es_mask]
        clf = make_classifier(model_name, y.iloc[fit_idx], random_state + fold, weight_scheme='balanced')
        fit_classifier(clf, model_name, X.iloc[fit_idx], y.iloc[fit_idx], X.iloc[es_idx], y.iloc[es_idx])
        p = clf.predict_proba(X.iloc[va])[:, 1]
        oof[va] = p
        fold_ap.append(float(average_precision_score(y.iloc[va], p)))
        print(f'  {model_name} builtin fold {fold}/{CV_N_SPLITS} 完成')
    return oof, fold_ap


def cross_val_weighted_oof(model_name, data, feature_cols, beta, eta, kappa,
                           random_state=CV_RANDOM_STATE):
    X, y = data[feature_cols], data['Class'].astype(int)
    amount = data['Amount'].astype(float)
    oof = np.full(len(data), np.nan, dtype=float)
    fold_ap, weight_states = [], []
    for fold, (tr, va) in enumerate(iter_purged_cv_folds(data), start=1):
        fit_mask, es_mask = temporal_es_masks(y.iloc[tr])
        fit_idx, es_idx = tr[fit_mask], tr[es_mask]
        state = fit_weight_state(amount.iloc[fit_idx], y.iloc[fit_idx], beta, eta, kappa,
                                 clip_quantile=0.95)
        sw_fit = transform_business_weight(amount.iloc[fit_idx], y.iloc[fit_idx], state)
        clf = make_classifier(model_name, y.iloc[fit_idx], random_state + fold, weight_scheme='no_weight')
        fit_classifier(
            clf, model_name, X.iloc[fit_idx], y.iloc[fit_idx], X.iloc[es_idx], y.iloc[es_idx],
            sample_weight=sw_fit,
        )
        p = clf.predict_proba(X.iloc[va])[:, 1]
        oof[va] = p
        fold_ap.append(float(average_precision_score(y.iloc[va], p)))
        weight_states.append(state)
        print(f'  {model_name} weighted fold {fold}/{CV_N_SPLITS} 完成 '
              f'(beta={beta:.4g}, eta={eta:.4g}, kappa={kappa:.4g})')
    return oof, fold_ap, weight_states

# %% [markdown]
# ## 4. Top-K 固定告警量指标与窄表
#
# `Top-K` 表示只审核风险分数最高的 K 笔交易。baseline 在 calibration 上用最佳 F1 阈值得到告警率 $K_{cal}/N_{cal}$；候选在 calibration 使用相同 $K_{cal}$，evaluation 使用相同比例对应的 $K_{eval}$。
#
# 这样每个模型的告警工作量完全一致，不会再出现 `matchedFP` 从 calibration 迁移到 evaluation 后失控的问题。参数只按 `*_cal_atK` 选；`*_eval_atK` 只用于最终验收。
#
# notebook 不再展示 TP、TN、FraudAmount、MicroFN 等冗余列；它们仍保存在完整 CSV 供审计。

# %%
# §4 prep：cal/eval、F1 与 Top-K
def oof_cal_mask(y, cal_frac=OOF_CAL_FRAC, min_fraud_cal=OOF_CAL_MIN_FRAUD,
                 max_frac=OOF_CAL_MAX_FRAC):
    y = np.asarray(y, dtype=int)
    fraud_idx, norm_idx = np.flatnonzero(y == 1), np.flatnonzero(y == 0)
    frac = cal_frac
    while frac <= max_frac + 1e-9:
        nf = min(max(min_fraud_cal, int(len(fraud_idx) * frac)), len(fraud_idx) - 1)
        nn = min(max(1, int(len(norm_idx) * frac)), len(norm_idx) - 1)
        mask = np.zeros(len(y), dtype=bool)
        mask[fraud_idx[:nf]] = True
        mask[norm_idx[:nn]] = True
        if int(y[mask].sum()) >= min(min_fraud_cal, len(fraud_idx) - 1):
            return mask
        frac += 0.05
    raise ValueError('无法构造 OOF calibration 段')


def best_f1_threshold(y, p):
    precision, recall, threshold = precision_recall_curve(y, p)
    if not len(threshold):
        return 0.5
    f1 = 2 * precision[:-1] * recall[:-1] / np.maximum(precision[:-1] + recall[:-1], 1e-12)
    return float(threshold[int(np.nanargmax(f1))])


def confusion(y, pred):
    tn, fp, fn, tp = confusion_matrix(y, pred, labels=[0, 1]).ravel()
    precision = tp / max(tp + fp, 1)
    recall = tp / max(tp + fn, 1)
    f1 = 2 * precision * recall / max(precision + recall, 1e-12)
    return dict(TN=int(tn), FP=int(fp), FN=int(fn), TP=int(tp),
                Precision=float(precision), Recall=float(recall), F1=float(f1))


def metrics_at_top_k(y, amount, p, k, suffix):
    y = np.asarray(y, dtype=int)
    amount = np.asarray(amount, dtype=float)
    p = np.asarray(p, dtype=float)
    k = int(np.clip(int(k), 1, len(y)))
    order = np.argsort(-p, kind='mergesort')
    pred = np.zeros(len(y), dtype=bool)
    pred[order[:k]] = True
    out = confusion(y, pred)
    fraud, caught = y == 1, (y == 1) & pred
    total_amount = float(amount[fraud].sum())
    caught_amount = float(amount[caught].sum())
    micro = fraud & (amount <= 1.0)
    micro_tp = int((micro & pred).sum())
    out.update({
        'K': k,
        'AmountRecall': caught_amount / total_amount if total_amount else np.nan,
        'MissedAmount': total_amount - caught_amount,
        'MicroRecall': micro_tp / int(micro.sum()) if micro.any() else np.nan,
        'MicroFN': int(micro.sum()) - micro_tp,
        'FraudAmount': total_amount,
    })
    assert out['TP'] + out['FP'] == k
    return {f'{name}_{suffix}_atK': value for name, value in out.items()}

# %%
# §4 prep：完整评价与窄表展示
def evaluate_oof_business(data, oof, fold_ap, alert_rate=None):
    finite = np.isfinite(oof)
    y = data.loc[finite, 'Class'].astype(int).to_numpy()
    amount = data.loc[finite, 'Amount'].astype(float).to_numpy()
    p = np.asarray(oof, dtype=float)[finite]
    cal, ev = oof_cal_mask(y), None
    ev = ~cal
    t_f1 = best_f1_threshold(y[cal], p[cal])
    if alert_rate is None:
        alert_rate = float((p[cal] >= t_f1).mean())
    k_cal = max(1, int(round(alert_rate * int(cal.sum()))))
    k_eval = max(1, int(round(alert_rate * int(ev.sum()))))
    result = {
        'AUC-PR_mean': float(np.mean(fold_ap)), 'AUC-PR_std': float(np.std(fold_ap)),
        'AUC-PR_cal': float(average_precision_score(y[cal], p[cal])),
        'AUC-PR_eval': float(average_precision_score(y[ev], p[ev])),
        'alert_rate': float(alert_rate), 'n_cal': int(cal.sum()), 'n_eval': int(ev.sum()),
        'n_fraud_cal': int(y[cal].sum()), 'n_fraud_eval': int(y[ev].sum()),
    }
    result.update(metrics_at_top_k(y[cal], amount[cal], p[cal], k_cal, 'cal'))
    result.update(metrics_at_top_k(y[ev], amount[ev], p[ev], k_eval, 'eval'))
    return result


def compact_classification_table(frame, split='eval'):
    cols = ['feature_group', 'model', 'experiment', 'loss_kind', 'beta', 'eta', 'kappa',
            f'AUC-PR_{split}', f'F1_{split}_atK', f'Precision_{split}_atK',
            f'Recall_{split}_atK', f'FP_{split}_atK', f'FN_{split}_atK']
    rename = {'feature_group': '特征组', 'model': '模型', 'experiment': '实验',
              'loss_kind': '损失', 'beta': 'β', 'eta': 'η', 'kappa': 'κ',
              f'AUC-PR_{split}': 'AUC-PR', f'F1_{split}_atK': 'F1@K',
              f'Precision_{split}_atK': 'Precision@K', f'Recall_{split}_atK': 'Recall@K',
              f'FP_{split}_atK': 'FP@K', f'FN_{split}_atK': 'FN@K'}
    out = frame[[c for c in cols if c in frame.columns]].copy()
    out['experiment'] = out['experiment'].replace({
        'exp0_builtin': '原始 BASE', 'stage2_builtin': '原始 BASE',
        'exp0_neutral': '中性 BASE', 'stage2_neutral': '中性 BASE',
        'stage2_selected': '选中参数',
    })
    return out.rename(columns=rename)


def compact_business_table(frame, split='eval'):
    cols = ['feature_group', 'model', 'experiment', 'beta', 'eta', 'kappa',
            f'AmountRecall_{split}_atK', f'MissedAmount_{split}_atK',
            f'MicroRecall_{split}_atK']
    rename = {'feature_group': '特征组', 'model': '模型', 'experiment': '实验',
              'beta': 'β', 'eta': 'η', 'kappa': 'κ',
              f'AmountRecall_{split}_atK': '金额召回@K',
              f'MissedAmount_{split}_atK': '漏报金额@K',
              f'MicroRecall_{split}_atK': '小额召回@K'}
    out = frame[[c for c in cols if c in frame.columns]].copy()
    out['experiment'] = out['experiment'].replace({
        'exp0_builtin': '原始 BASE', 'stage2_builtin': '原始 BASE',
        'exp0_neutral': '中性 BASE', 'stage2_neutral': '中性 BASE',
        'stage2_selected': '选中参数',
    })
    return out.rename(columns=rename)


def with_base_rows(frame, baseline_source):
    '''为每个结果表前置原始 BASE 与中性 BASE；只改变展示，不改变原始 CSV。'''
    if frame.empty:
        return frame.copy()
    base_names = ['exp0_builtin', 'exp0_neutral', 'stage2_builtin', 'stage2_neutral']
    wanted_models = set(frame['model'].astype(str))
    wanted_groups = set(frame['feature_group'].astype(str))
    base = baseline_source[
        baseline_source['experiment'].isin(base_names)
        & baseline_source['model'].astype(str).isin(wanted_models)
        & baseline_source['feature_group'].astype(str).isin(wanted_groups)
    ].copy()
    combined = pd.concat([base, frame], ignore_index=True, sort=False)
    key = [c for c in ['feature_group', 'model', 'experiment', 'loss_kind', 'beta', 'eta', 'kappa']
           if c in combined.columns]
    combined = combined.drop_duplicates(key, keep='first')
    combined['_display_order'] = combined['experiment'].map({
        'exp0_builtin': 0, 'stage2_builtin': 0,
        'exp0_neutral': 1, 'stage2_neutral': 1,
    }).fillna(2)
    combined = combined.sort_values(['feature_group', 'model', '_display_order', 'experiment'])
    return combined.drop(columns='_display_order').reset_index(drop=True)

# %% [markdown]
# ## 5. 第一阶段粗网格：实验 0、1、2、3
#
# - 实验 0：比较内置 balanced 与 neutral sample-weight。
# - 实验 1：只搜索 beta。
# - 实验 2：固定暂定 beta，搜索 eta。
# - 实验 3：固定暂定 beta/eta，搜索 kappa。
#
# 实验 1–3 都在 neutral 路径上运行，所有 provisional 参数均按 calibration Top-K 指标选择。

# %%
# §5 prep：V2 OOF 缓存与运行单元
def cache_key(model_name, feature_group, loss_kind, beta, eta, kappa):
    raw = f'v2|{model_name}|{feature_group}|{loss_kind}|{beta:.8g}|{eta:.8g}|{kappa:.8g}'
    return hashlib.sha1(raw.encode('utf-8')).hexdigest()[:16]


def get_oof(model_name, data, feature_cols, feature_group, loss_kind,
            beta=0.0, eta=0.0, kappa=1.0):
    path = OOF_CACHE_DIR / f'{model_name}_{feature_group}_{loss_kind}_{cache_key(model_name, feature_group, loss_kind, beta, eta, kappa)}.npz'
    if path.is_file() and not FORCE_RERUN:
        saved = np.load(path, allow_pickle=False)
        return saved['oof'], saved['fold_ap'].tolist()
    if loss_kind == 'builtin':
        oof, fold_ap = cross_val_builtin_oof(model_name, data, feature_cols)
    else:
        oof, fold_ap, _ = cross_val_weighted_oof(model_name, data, feature_cols, beta, eta, kappa)
    np.savez_compressed(path, oof=oof, fold_ap=np.asarray(fold_ap, dtype=float))
    return oof, fold_ap


def run_config(model_name, data, feature_cols, feature_group, experiment, loss_kind,
               beta=0.0, eta=0.0, kappa=1.0, alert_rate=None):
    print(f'\n[{feature_group} | {model_name}] {experiment}: {loss_kind}, '
          f'beta={beta:.4g}, eta={eta:.4g}, kappa={kappa:.4g}')
    oof, fold_ap = get_oof(model_name, data, feature_cols, feature_group, loss_kind,
                           beta, eta, kappa)
    row = evaluate_oof_business(data, oof, fold_ap, alert_rate=alert_rate)
    row.update({'feature_group': feature_group, 'model': model_name,
                'experiment': experiment, 'loss_kind': loss_kind,
                'beta': float(beta), 'eta': float(eta), 'kappa': float(kappa)})
    return row


def best_on_cal(frame, model_name, experiments=None):
    part = frame[frame['model'] == model_name].copy()
    if experiments is not None:
        part = part[part['experiment'].isin(experiments)]
    return part.sort_values(
        ['AmountRecall_cal_atK', 'MicroRecall_cal_atK', 'AUC-PR_cal'],
        ascending=[False, False, False],
    ).iloc[0]

# %%
# §5 prep：粗网格实验 0–3
def run_stage1(data):
    rows = []
    for model_name in MODELS:
        anchor = run_config(model_name, data, BASE_FEATURES, 'BASE', 'exp0_builtin', 'builtin')
        rows.append(anchor)
        rate = anchor['alert_rate']
        neutral = run_config(model_name, data, BASE_FEATURES, 'BASE', 'exp0_neutral',
                             'amount_aware', 0, 0, 1, rate)
        rows.append(neutral)
        if abs(neutral['AUC-PR_mean'] - anchor['AUC-PR_mean']) > PARITY_AUC_TOL:
            print(f'警告：{model_name} neutral 与 builtin AUC-PR 差值超过 {PARITY_AUC_TOL}')

        for beta in BETA_GRID:
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'exp1_beta',
                                   'amount_aware', beta, 0, 1, rate))
        beta_best = float(best_on_cal(pd.DataFrame(rows), model_name, ['exp1_beta'])['beta'])
        for eta in ETA_GRID:
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'exp2_eta',
                                   'amount_aware', beta_best, eta, 1, rate))
        best2 = best_on_cal(pd.DataFrame(rows), model_name, ['exp1_beta', 'exp2_eta'])
        beta_best, eta_best = float(best2['beta']), float(best2['eta'])
        for kappa in KAPPA_GRID:
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'exp3_kappa',
                                   'amount_aware', beta_best, eta_best, kappa, rate))
        pd.DataFrame(rows).to_csv(OUT_COARSE / 'coarse_checkpoint.csv', index=False)
    result = pd.DataFrame(rows)
    result.to_csv(OUT_COARSE / 'coarse_results.csv', index=False)
    return result

# %%
# §5 exec：粗网格
if RUN_COARSE_GRID:
    coarse_results = run_stage1(df_all)
else:
    path = OUT_COARSE / 'coarse_results.csv'
    coarse_results = pd.read_csv(path) if path.is_file() else pd.DataFrame()
    print('RUN_COARSE_GRID=False；已有粗网格行数:', len(coarse_results))

if not coarse_results.empty:
    coarse_display = with_base_rows(coarse_results, coarse_results)
    print('分类核心表（calibration，用于选参）')
    display(compact_classification_table(coarse_display, 'cal').round(5))
    print('业务核心表（calibration，用于选参）')
    display(compact_business_table(coarse_display, 'cal').round(5))
# Out:
# [BASE | LightGBM] exp0_builtin: builtin, beta=0, eta=0, kappa=1
#   LightGBM builtin fold 1/5 完成
#   LightGBM builtin fold 2/5 完成
#   LightGBM builtin fold 3/5 完成
#   LightGBM builtin fold 4/5 完成
#   LightGBM builtin fold 5/5 完成
#
# [BASE | LightGBM] exp0_neutral: amount_aware, beta=0, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [BASE | LightGBM] exp1_beta: amount_aware, beta=0.25, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=0, kappa=1)
#
# [BASE | LightGBM] exp1_beta: amount_aware, beta=0.5, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.5, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.5, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.5, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.5, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.5, eta=0, kappa=1)
#
# [BASE | LightGBM] exp1_beta: amount_aware, beta=1, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=1, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=1, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=1, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=1, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=1, eta=0, kappa=1)
#
# [BASE | LightGBM] exp1_beta: amount_aware, beta=2, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=2, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=2, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=2, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=2, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=2, eta=0, kappa=1)
#
# [BASE | LightGBM] exp1_beta: amount_aware, beta=4, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=4, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=4, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=4, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=4, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=4, eta=0, kappa=1)
#
# [BASE | LightGBM] exp2_eta: amount_aware, beta=0.25, eta=0.25, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=0.25, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=0.25, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=0.25, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=0.25, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=0.25, kappa=1)
#
# [BASE | LightGBM] exp2_eta: amount_aware, beta=0.25, eta=0.5, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=0.5, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=0.5, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=0.5, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=0.5, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=0.5, kappa=1)
#
# [BASE | LightGBM] exp2_eta: amount_aware, beta=0.25, eta=1, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=1, kappa=1)
#
# [BASE | LightGBM] exp2_eta: amount_aware, beta=0.25, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1)
#
# [BASE | LightGBM] exp3_kappa: amount_aware, beta=0.25, eta=2, kappa=0.5
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=0.5)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=0.5)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=0.5)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=0.5)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=0.5)
#
# [BASE | LightGBM] exp3_kappa: amount_aware, beta=0.25, eta=2, kappa=0.75
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=0.75)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=0.75)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=0.75)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=0.75)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=0.75)
#
# [BASE | LightGBM] exp3_kappa: amount_aware, beta=0.25, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1)
#
# [BASE | LightGBM] exp3_kappa: amount_aware, beta=0.25, eta=2, kappa=1.25
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1.25)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1.25)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1.25)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1.25)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1.25)
#
# [BASE | LightGBM] exp3_kappa: amount_aware, beta=0.25, eta=2, kappa=1.5
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1.5)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1.5)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1.5)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1.5)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1.5)
#
# [BASE | XGBoost] exp0_builtin: builtin, beta=0, eta=0, kappa=1
#   XGBoost builtin fold 1/5 完成
#   XGBoost builtin fold 2/5 完成
#   XGBoost builtin fold 3/5 完成
#   XGBoost builtin fold 4/5 完成
#   XGBoost builtin fold 5/5 完成
#
# [BASE | XGBoost] exp0_neutral: amount_aware, beta=0, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [BASE | XGBoost] exp1_beta: amount_aware, beta=0.25, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=0.25, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=0.25, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=0.25, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=0.25, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=0.25, eta=0, kappa=1)
#
# [BASE | XGBoost] exp1_beta: amount_aware, beta=0.5, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=0.5, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=0.5, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=0.5, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=0.5, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=0.5, eta=0, kappa=1)
#
# [BASE | XGBoost] exp1_beta: amount_aware, beta=1, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=1, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=1, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=1, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=1, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=1, eta=0, kappa=1)
#
# [BASE | XGBoost] exp1_beta: amount_aware, beta=2, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=2, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=2, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=2, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=2, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=2, eta=0, kappa=1)
#
# [BASE | XGBoost] exp1_beta: amount_aware, beta=4, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=0, kappa=1)
#
# [BASE | XGBoost] exp2_eta: amount_aware, beta=4, eta=0.25, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=0.25, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=0.25, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=0.25, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=0.25, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=0.25, kappa=1)
#
# [BASE | XGBoost] exp2_eta: amount_aware, beta=4, eta=0.5, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=0.5, kappa=1)
#
# [BASE | XGBoost] exp2_eta: amount_aware, beta=4, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1)
#
# [BASE | XGBoost] exp2_eta: amount_aware, beta=4, eta=2, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=2, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=2, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=2, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=2, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=2, kappa=1)
#
# [BASE | XGBoost] exp3_kappa: amount_aware, beta=4, eta=1, kappa=0.5
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=0.5)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=0.5)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=0.5)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=0.5)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=0.5)
#
# [BASE | XGBoost] exp3_kappa: amount_aware, beta=4, eta=1, kappa=0.75
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=0.75)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=0.75)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=0.75)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=0.75)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=0.75)
#
# [BASE | XGBoost] exp3_kappa: amount_aware, beta=4, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1)
#
# [BASE | XGBoost] exp3_kappa: amount_aware, beta=4, eta=1, kappa=1.25
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1.25)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1.25)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1.25)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1.25)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1.25)
#
# [BASE | XGBoost] exp3_kappa: amount_aware, beta=4, eta=1, kappa=1.5
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1.5)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1.5)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1.5)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1.5)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1.5)
# 分类核心表（calibration，用于选参）
#      特征组        模型          实验            损失     β     η     κ   AUC-PR     F1@K  Precision@K  Recall@K  FP@K  FN@K
# 0   BASE  LightGBM     原始 BASE       builtin  0.00  0.00  1.00  0.77364  0.82353      0.94030   0.73256     4    23
# 1   BASE  LightGBM     中性 BASE  amount_aware  0.00  0.00  1.00  0.76649  0.81046      0.92537   0.72093     5    24
# 2   BASE  LightGBM   exp1_beta  amount_aware  0.25  0.00  1.00  0.77099  0.81046      0.92537   0.72093     5    24
# 3   BASE  LightGBM   exp1_beta  amount_aware  0.50  0.00  1.00  0.76860  0.81046      0.92537   0.72093     5    24
# 4   BASE  LightGBM   exp1_beta  amount_aware  1.00  0.00  1.00  0.76367  0.81046      0.92537   0.72093     5    24
# 5   BASE  LightGBM   exp1_beta  amount_aware  2.00  0.00  1.00  0.76489  0.79739      0.91045   0.70930     6    25
# 6   BASE  LightGBM   exp1_beta  amount_aware  4.00  0.00  1.00  0.76227  0.79739      0.91045   0.70930     6    25
# 7   BASE  LightGBM    exp2_eta  amount_aware  0.25  0.25  1.00  0.76937  0.79739      0.91045   0.70930     6    25
# 8   BASE  LightGBM    exp2_eta  amount_aware  0.25  0.50  1.00  0.77074  0.81046      0.92537   0.72093     5    24
# 9   BASE  LightGBM    exp2_eta  amount_aware  0.25  1.00  1.00  0.77276  0.82353      0.94030   0.73256     4    23
# 10  BASE  LightGBM    exp2_eta  amount_aware  0.25  2.00  1.00  0.77255  0.82353      0.94030   0.73256     4    23
# 11  BASE  LightGBM  exp3_kappa  amount_aware  0.25  2.00  0.50  0.77053  0.81046      0.92537   0.72093     5    24
# 12  BASE  LightGBM  exp3_kappa  amount_aware  0.25  2.00  0.75  0.77234  0.81046      0.92537   0.72093     5    24
# 13  BASE  LightGBM  exp3_kappa  amount_aware  0.25  2.00  1.00  0.77255  0.82353      0.94030   0.73256     4    23
# 14  BASE  LightGBM  exp3_kappa  amount_aware  0.25  2.00  1.25  0.77185  0.82353      0.94030   0.73256     4    23
# 15  BASE  LightGBM  exp3_kappa  amount_aware  0.25  2.00  1.50  0.77073  0.81046      0.92537   0.72093     5    24
# 16  BASE   XGBoost     原始 BASE       builtin  0.00  0.00  1.00  0.75594  0.80769      0.90000   0.73256     7    23
# 17  BASE   XGBoost     中性 BASE  amount_aware  0.00  0.00  1.00  0.75539  0.78205      0.87143   0.70930     9    25
# 18  BASE   XGBoost   exp1_beta  amount_aware  0.25  0.00  1.00  0.75306  0.78205      0.87143   0.70930     9    25
# 19  BASE   XGBoost   exp1_beta  amount_aware  0.50  0.00  1.00  0.75271  0.79487      0.88571   0.72093     8    24
# 20  BASE   XGBoost   exp1_beta  amount_aware  1.00  0.00  1.00  0.75959  0.78205      0.87143   0.70930     9    25
# 21  BASE   XGBoost   exp1_beta  amount_aware  2.00  0.00  1.00  0.75126  0.80769      0.90000   0.73256     7    23
# 22  BASE   XGBoost   exp1_beta  amount_aware  4.00  0.00  1.00  0.75619  0.80769      0.90000   0.73256     7    23
# 23  BASE   XGBoost    exp2_eta  amount_aware  4.00  0.25  1.00  0.75632  0.80769      0.90000   0.73256     7    23
# 24  BASE   XGBoost    exp2_eta  amount_aware  4.00  0.50  1.00  0.75426  0.78205      0.87143   0.70930     9    25
# 25  BASE   XGBoost    exp2_eta  amount_aware  4.00  1.00  1.00  0.75716  0.80769      0.90000   0.73256     7    23
# 26  BASE   XGBoost    exp2_eta  amount_aware  4.00  2.00  1.00  0.75600  0.79487      0.88571   0.72093     8    24
# 27  BASE   XGBoost  exp3_kappa  amount_aware  4.00  1.00  0.50  0.75624  0.80769      0.90000   0.73256     7    23
# 28  BASE   XGBoost  exp3_kappa  amount_aware  4.00  1.00  0.75  0.75463  0.79487      0.88571   0.72093     8    24
# 29  BASE   XGBoost  exp3_kappa  amount_aware  4.00  1.00  1.00  0.75716  0.80769      0.90000   0.73256     7    23
# 30  BASE   XGBoost  exp3_kappa  amount_aware  4.00  1.00  1.25  0.75775  0.79487      0.88571   0.72093     8    24
# 31  BASE   XGBoost  exp3_kappa  amount_aware  4.00  1.00  1.50  0.75712  0.78205      0.87143   0.70930     9    25
# 业务核心表（calibration，用于选参）
#      特征组        模型          实验     β     η     κ   金额召回@K   漏报金额@K   小额召回@K
# 0   BASE  LightGBM     原始 BASE  0.00  0.00  1.00  0.76980  2782.79  0.81250
# 1   BASE  LightGBM     中性 BASE  0.00  0.00  1.00  0.76971  2783.79  0.78125
# 2   BASE  LightGBM   exp1_beta  0.25  0.00  1.00  0.76260  2869.79  0.81250
# 3   BASE  LightGBM   exp1_beta  0.50  0.00  1.00  0.76260  2869.79  0.81250
# 4   BASE  LightGBM   exp1_beta  1.00  0.00  1.00  0.73619  3188.99  0.84375
# 5   BASE  LightGBM   exp1_beta  2.00  0.00  1.00  0.73571  3194.90  0.84375
# 6   BASE  LightGBM   exp1_beta  4.00  0.00  1.00  0.73611  3189.99  0.81250
# 7   BASE  LightGBM    exp2_eta  0.25  0.25  1.00  0.76203  2876.70  0.81250
# 8   BASE  LightGBM    exp2_eta  0.25  0.50  1.00  0.76988  2781.79  0.78125
# 9   BASE  LightGBM    exp2_eta  0.25  1.00  1.00  0.76988  2781.79  0.81250
# 10  BASE  LightGBM    exp2_eta  0.25  2.00  1.00  0.77151  2762.06  0.78125
# 11  BASE  LightGBM  exp3_kappa  0.25  2.00  0.50  0.76988  2781.79  0.78125
# 12  BASE  LightGBM  exp3_kappa  0.25  2.00  0.75  0.76988  2781.79  0.78125
# 13  BASE  LightGBM  exp3_kappa  0.25  2.00  1.00  0.77151  2762.06  0.78125
# 14  BASE  LightGBM  exp3_kappa  0.25  2.00  1.25  0.76988  2781.79  0.81250
# 15  BASE  LightGBM  exp3_kappa  0.25  2.00  1.50  0.76980  2782.79  0.78125
# 16  BASE   XGBoost     原始 BASE  0.00  0.00  1.00  0.76260  2869.79  0.84375
# 17  BASE   XGBoost     中性 BASE  0.00  0.00  1.00  0.73619  3188.99  0.81250
# 18  BASE   XGBoost   exp1_beta  0.25  0.00  1.00  0.73619  3188.99  0.81250
# 19  BASE   XGBoost   exp1_beta  0.50  0.00  1.00  0.73619  3188.99  0.84375
# 20  BASE   XGBoost   exp1_beta  1.00  0.00  1.00  0.73619  3188.99  0.81250
# 21  BASE   XGBoost   exp1_beta  2.00  0.00  1.00  0.76260  2869.79  0.84375
# 22  BASE   XGBoost   exp1_beta  4.00  0.00  1.00  0.76260  2869.79  0.84375
# 23  BASE   XGBoost    exp2_eta  4.00  0.25  1.00  0.76260  2869.79  0.84375
# 24  BASE   XGBoost    exp2_eta  4.00  0.50  1.00  0.73619  3188.99  0.81250
# 25  BASE   XGBoost    exp2_eta  4.00  1.00  1.00  0.76260  2869.79  0.84375
# 26  BASE   XGBoost    exp2_eta  4.00  2.00  1.00  0.76260  2869.79  0.81250
# 27  BASE   XGBoost  exp3_kappa  4.00  1.00  0.50  0.76260  2869.79  0.84375
# 28  BASE   XGBoost  exp3_kappa  4.00  1.00  0.75  0.76260  2869.79  0.81250
# 29  BASE   XGBoost  exp3_kappa  4.00  1.00  1.00  0.76260  2869.79  0.84375
# 30  BASE   XGBoost  exp3_kappa  4.00  1.00  1.25  0.76260  2869.79  0.81250
# 31  BASE   XGBoost  exp3_kappa  4.00  1.00  1.50  0.73619  3188.99  0.81250

# %% [markdown]
# ## 6. 局部精细网格
#
# 在粗网格最优点附近依次细化 beta、eta、kappa，每一步只改变一个参数。这样比 5×5×5 全笛卡尔积更节省计算，也更容易解释是哪一个参数带来变化。

# %%
# §6 prep：局部精细网格
def local_values(center, name):
    center = float(center)
    if name in ('beta', 'eta'):
        if center <= 1e-12:
            return [0.0, 0.05, 0.1, 0.2, 0.35]
        step = max(0.05, center * 0.25)
        return sorted(set(round(max(0.0, center + offset * step), 6) for offset in [-2, -1, 0, 1, 2]))
    step = max(0.05, center * 0.1)
    return sorted(set(round(float(np.clip(center + offset * step, 0.25, 2.0)), 6)
                      for offset in [-2, -1, 0, 1, 2]))


def run_fine_grid(data, coarse):
    rows = []
    for model_name in MODELS:
        anchor = coarse[(coarse.model == model_name) & (coarse.experiment == 'exp0_builtin')].iloc[0]
        rate = float(anchor['alert_rate'])
        base = best_on_cal(coarse[coarse.loss_kind == 'amount_aware'], model_name,
                           ['exp1_beta', 'exp2_eta', 'exp3_kappa'])
        beta, eta, kappa = float(base.beta), float(base.eta), float(base.kappa)
        for value in local_values(beta, 'beta'):
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'fine_beta',
                                   'amount_aware', value, eta, kappa, rate))
        beta = float(best_on_cal(pd.DataFrame(rows), model_name, ['fine_beta']).beta)
        for value in local_values(eta, 'eta'):
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'fine_eta',
                                   'amount_aware', beta, value, kappa, rate))
        best_eta = best_on_cal(pd.DataFrame(rows), model_name, ['fine_beta', 'fine_eta'])
        beta, eta = float(best_eta.beta), float(best_eta.eta)
        for value in local_values(kappa, 'kappa'):
            rows.append(run_config(model_name, data, BASE_FEATURES, 'BASE', 'fine_kappa',
                                   'amount_aware', beta, eta, value, rate))
        pd.DataFrame(rows).to_csv(OUT_FINE / 'fine_grid_checkpoint.csv', index=False)
    result = pd.DataFrame(rows)
    result.to_csv(OUT_FINE / 'fine_grid_results.csv', index=False)
    return result

# %%
# §6 exec：局部精细网格
if RUN_FINE_GRID:
    if coarse_results.empty:
        raise RuntimeError('请先完成粗网格')
    fine_results = run_fine_grid(df_all, coarse_results)
else:
    path = OUT_FINE / 'fine_grid_results.csv'
    fine_results = pd.read_csv(path) if path.is_file() else pd.DataFrame()
    print('RUN_FINE_GRID=False；已有精细网格行数:', len(fine_results))
if not fine_results.empty:
    fine_display = with_base_rows(fine_results, coarse_results)
    display(compact_business_table(fine_display, 'cal').round(5))
# Out:
# [BASE | LightGBM] fine_beta: amount_aware, beta=0.125, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.125, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.125, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.125, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.125, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.125, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_beta: amount_aware, beta=0.1875, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.1875, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.1875, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.1875, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.1875, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.1875, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_beta: amount_aware, beta=0.25, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_beta: amount_aware, beta=0.3125, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.3125, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.3125, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.3125, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.3125, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.3125, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_beta: amount_aware, beta=0.375, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.375, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.375, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.375, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.375, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.375, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_eta: amount_aware, beta=0.25, eta=1, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=1, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=1, kappa=1)
#
# [BASE | LightGBM] fine_eta: amount_aware, beta=0.25, eta=1.5, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=1.5, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=1.5, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=1.5, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=1.5, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=1.5, kappa=1)
#
# [BASE | LightGBM] fine_eta: amount_aware, beta=0.25, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_eta: amount_aware, beta=0.25, eta=2.5, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2.5, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2.5, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2.5, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2.5, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2.5, kappa=1)
#
# [BASE | LightGBM] fine_eta: amount_aware, beta=0.25, eta=3, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=3, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=3, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=3, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=3, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=3, kappa=1)
#
# [BASE | LightGBM] fine_kappa: amount_aware, beta=0.25, eta=2, kappa=0.8
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=0.8)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=0.8)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=0.8)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=0.8)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=0.8)
#
# [BASE | LightGBM] fine_kappa: amount_aware, beta=0.25, eta=2, kappa=0.9
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=0.9)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=0.9)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=0.9)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=0.9)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=0.9)
#
# [BASE | LightGBM] fine_kappa: amount_aware, beta=0.25, eta=2, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1)
#
# [BASE | LightGBM] fine_kappa: amount_aware, beta=0.25, eta=2, kappa=1.1
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1.1)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1.1)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1.1)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1.1)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1.1)
#
# [BASE | LightGBM] fine_kappa: amount_aware, beta=0.25, eta=2, kappa=1.2
#   LightGBM weighted fold 1/5 完成 (beta=0.25, eta=2, kappa=1.2)
#   LightGBM weighted fold 2/5 完成 (beta=0.25, eta=2, kappa=1.2)
#   LightGBM weighted fold 3/5 完成 (beta=0.25, eta=2, kappa=1.2)
#   LightGBM weighted fold 4/5 完成 (beta=0.25, eta=2, kappa=1.2)
#   LightGBM weighted fold 5/5 完成 (beta=0.25, eta=2, kappa=1.2)
#
# [BASE | XGBoost] fine_beta: amount_aware, beta=2, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=2, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=2, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=2, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=2, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=2, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_beta: amount_aware, beta=3, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=3, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=3, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=3, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=3, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=3, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_beta: amount_aware, beta=4, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_beta: amount_aware, beta=5, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=5, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=5, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=5, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=5, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=5, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_beta: amount_aware, beta=6, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=6, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=6, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=6, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=6, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=6, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_eta: amount_aware, beta=4, eta=0.5, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=0.5, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=0.5, kappa=1)
#
# [BASE | XGBoost] fine_eta: amount_aware, beta=4, eta=0.75, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=0.75, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=0.75, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=0.75, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=0.75, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=0.75, kappa=1)
#
# [BASE | XGBoost] fine_eta: amount_aware, beta=4, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_eta: amount_aware, beta=4, eta=1.25, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1.25, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1.25, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1.25, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1.25, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1.25, kappa=1)
#
# [BASE | XGBoost] fine_eta: amount_aware, beta=4, eta=1.5, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1.5, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1.5, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1.5, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1.5, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1.5, kappa=1)
#
# [BASE | XGBoost] fine_kappa: amount_aware, beta=4, eta=1, kappa=0.8
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=0.8)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=0.8)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=0.8)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=0.8)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=0.8)
#
# [BASE | XGBoost] fine_kappa: amount_aware, beta=4, eta=1, kappa=0.9
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=0.9)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=0.9)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=0.9)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=0.9)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=0.9)
#
# [BASE | XGBoost] fine_kappa: amount_aware, beta=4, eta=1, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1)
#
# [BASE | XGBoost] fine_kappa: amount_aware, beta=4, eta=1, kappa=1.1
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1.1)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1.1)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1.1)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1.1)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1.1)
#
# [BASE | XGBoost] fine_kappa: amount_aware, beta=4, eta=1, kappa=1.2
#   XGBoost weighted fold 1/5 完成 (beta=4, eta=1, kappa=1.2)
#   XGBoost weighted fold 2/5 完成 (beta=4, eta=1, kappa=1.2)
#   XGBoost weighted fold 3/5 完成 (beta=4, eta=1, kappa=1.2)
#   XGBoost weighted fold 4/5 完成 (beta=4, eta=1, kappa=1.2)
#   XGBoost weighted fold 5/5 完成 (beta=4, eta=1, kappa=1.2)
#      特征组        模型          实验       β     η    κ   金额召回@K   漏报金额@K   小额召回@K
# 0   BASE  LightGBM     原始 BASE  0.0000  0.00  1.0  0.76980  2782.79  0.81250
# 1   BASE  LightGBM     中性 BASE  0.0000  0.00  1.0  0.76971  2783.79  0.78125
# 2   BASE  LightGBM   fine_beta  0.1250  2.00  1.0  0.76988  2781.79  0.78125
# 3   BASE  LightGBM   fine_beta  0.1875  2.00  1.0  0.76988  2781.79  0.78125
# 4   BASE  LightGBM   fine_beta  0.2500  2.00  1.0  0.77151  2762.06  0.78125
# 5   BASE  LightGBM   fine_beta  0.3125  2.00  1.0  0.76988  2781.79  0.81250
# 6   BASE  LightGBM   fine_beta  0.3750  2.00  1.0  0.76988  2781.79  0.81250
# 7   BASE  LightGBM    fine_eta  0.2500  1.00  1.0  0.76988  2781.79  0.81250
# 8   BASE  LightGBM    fine_eta  0.2500  1.50  1.0  0.76939  2787.70  0.81250
# 9   BASE  LightGBM    fine_eta  0.2500  2.00  1.0  0.77151  2762.06  0.78125
# 10  BASE  LightGBM    fine_eta  0.2500  2.50  1.0  0.76988  2781.79  0.81250
# 11  BASE  LightGBM    fine_eta  0.2500  3.00  1.0  0.76822  2801.83  0.81250
# 12  BASE  LightGBM  fine_kappa  0.2500  2.00  0.8  0.76980  2782.79  0.78125
# 13  BASE  LightGBM  fine_kappa  0.2500  2.00  0.9  0.76980  2782.79  0.78125
# 14  BASE  LightGBM  fine_kappa  0.2500  2.00  1.0  0.77151  2762.06  0.78125
# 15  BASE  LightGBM  fine_kappa  0.2500  2.00  1.1  0.76988  2781.79  0.78125
# 16  BASE  LightGBM  fine_kappa  0.2500  2.00  1.2  0.76980  2782.79  0.81250
# 17  BASE   XGBoost     原始 BASE  0.0000  0.00  1.0  0.76260  2869.79  0.84375
# 18  BASE   XGBoost     中性 BASE  0.0000  0.00  1.0  0.73619  3188.99  0.81250
# 19  BASE   XGBoost   fine_beta  2.0000  1.00  1.0  0.76260  2869.79  0.81250
# 20  BASE   XGBoost   fine_beta  3.0000  1.00  1.0  0.76260  2869.79  0.81250
# 21  BASE   XGBoost   fine_beta  4.0000  1.00  1.0  0.76260  2869.79  0.84375
# 22  BASE   XGBoost   fine_beta  5.0000  1.00  1.0  0.76260  2869.79  0.81250
# 23  BASE   XGBoost   fine_beta  6.0000  1.00  1.0  0.76260  2869.79  0.81250
# 24  BASE   XGBoost    fine_eta  4.0000  0.50  1.0  0.73619  3188.99  0.81250
# 25  BASE   XGBoost    fine_eta  4.0000  0.75  1.0  0.76260  2869.79  0.81250
# 26  BASE   XGBoost    fine_eta  4.0000  1.00  1.0  0.76260  2869.79  0.84375
# 27  BASE   XGBoost    fine_eta  4.0000  1.25  1.0  0.76260  2869.79  0.81250
# 28  BASE   XGBoost    fine_eta  4.0000  1.50  1.0  0.76260  2869.79  0.81250
# 29  BASE   XGBoost  fine_kappa  4.0000  1.00  0.8  0.76260  2869.79  0.84375
# 30  BASE   XGBoost  fine_kappa  4.0000  1.00  0.9  0.76260  2869.79  0.84375
# 31  BASE   XGBoost  fine_kappa  4.0000  1.00  1.0  0.76260  2869.79  0.84375
# 32  BASE   XGBoost  fine_kappa  4.0000  1.00  1.1  0.76260  2869.79  0.84375
# 33  BASE   XGBoost  fine_kappa  4.0000  1.00  1.2  0.76260  2869.79  0.81250

# %% [markdown]
# ## 7. Optuna 多目标搜索
#
# 使用 NSGA-II 同时最大化 calibration 段的：
#
# 1. `AmountRecall@K`；
# 2. `MicroRecall@K`；
# 3. AUC-PR。
#
# 搜索空间为 beta∈[0,6]、eta∈[0,6]、kappa∈[0.4,1.6]。默认每模型 30 trials，共约 300 次五折模型拟合；结果和 OOF 均可断点复用。多目标搜索不会保证存在优于 baseline 的参数，它只会更系统地描出可达到的 Pareto 边界。

# %%
# §7 prep：Optuna NSGA-II 多目标搜索
def run_optuna_multiobjective(data, coarse, n_trials=OPTUNA_N_TRIALS):
    all_rows, selected = [], {}
    for model_name in MODELS:
        anchor = coarse[(coarse.model == model_name) & (coarse.experiment == 'exp0_builtin')].iloc[0]
        rate = float(anchor['alert_rate'])

        def objective(trial):
            beta = trial.suggest_float('beta', 0.0, 6.0)
            eta = trial.suggest_float('eta', 0.0, 6.0)
            kappa = trial.suggest_float('kappa', 0.4, 1.6)
            row = run_config(model_name, data, BASE_FEATURES, 'BASE', 'optuna',
                             'amount_aware', beta, eta, kappa, rate)
            row['trial_number'] = trial.number
            all_rows.append(row)
            for key, value in row.items():
                if isinstance(value, (str, int, float, np.integer, np.floating)):
                    trial.set_user_attr(key, value.item() if hasattr(value, 'item') else value)
            return row['AmountRecall_cal_atK'], row['MicroRecall_cal_atK'], row['AUC-PR_cal']

        study = optuna.create_study(
            directions=['maximize', 'maximize', 'maximize'],
            sampler=optuna.samplers.NSGAIISampler(seed=CV_RANDOM_STATE),
            study_name=f'amount_loss_v2_{model_name}',
        )
        study.optimize(objective, n_trials=int(n_trials), show_progress_bar=True)
        trials = pd.DataFrame([t.user_attrs for t in study.trials if t.user_attrs])
        pareto_numbers = {t.number for t in study.best_trials}
        trials['pareto'] = trials['trial_number'].isin(pareto_numbers)
        trials.to_csv(OUT_OPTUNA / f'optuna_trials_{model_name}.csv', index=False)
        best = best_on_cal(trials[trials.pareto], model_name)
        selected[model_name] = {'beta': float(best.beta), 'eta': float(best.eta),
                                'kappa': float(best.kappa), 'source': 'optuna_pareto'}
    result = pd.DataFrame(all_rows)
    result.to_csv(OUT_OPTUNA / 'optuna_results.csv', index=False)
    (OUT_OPTUNA / 'optuna_selected.json').write_text(
        json.dumps(selected, ensure_ascii=False, indent=2), encoding='utf-8')
    return result, selected

# %%
# §7 exec：Optuna
if RUN_OPTUNA:
    if coarse_results.empty:
        raise RuntimeError('请先完成粗网格')
    optuna_results, optuna_selected = run_optuna_multiobjective(df_all, coarse_results)
else:
    path = OUT_OPTUNA / 'optuna_results.csv'
    optuna_results = pd.read_csv(path) if path.is_file() else pd.DataFrame()
    selected_path = OUT_OPTUNA / 'optuna_selected.json'
    optuna_selected = json.loads(selected_path.read_text(encoding='utf-8')) if selected_path.is_file() else {}
    print('RUN_OPTUNA=False；已有 Optuna 行数:', len(optuna_results))
if not optuna_results.empty:
    optuna_display = with_base_rows(optuna_results, coarse_results)
    display(compact_business_table(optuna_display, 'cal').round(5))
# Out:
# [I 2026-07-08 01:13:59,389] A new study created in memory with name: amount_loss_v2_LightGBM
#   0%|          | 0/30 [00:00<?, ?it/s]
# [BASE | LightGBM] optuna: amount_aware, beta=2.247, eta=5.704, kappa=1.278
#   LightGBM weighted fold 1/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   LightGBM weighted fold 2/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   LightGBM weighted fold 3/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   LightGBM weighted fold 4/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   LightGBM weighted fold 5/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
# [I 2026-07-08 01:14:07,585] Trial 0 finished with values: [0.7693075752850463, 0.8125, 0.7694979189405683] and parameters: {'beta': 2.247240713084175, 'eta': 5.704285838459497, 'kappa': 1.2783927301736862}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.592, eta=0.9361, kappa=0.5872
#   LightGBM weighted fold 1/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   LightGBM weighted fold 2/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   LightGBM weighted fold 3/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   LightGBM weighted fold 4/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   LightGBM weighted fold 5/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
# [I 2026-07-08 01:14:15,272] Trial 1 finished with values: [0.7625167619509297, 0.78125, 0.7634445631359563] and parameters: {'beta': 3.5919509051822196, 'eta': 0.9361118426546191, 'kappa': 0.5871934244034432}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=0.3485, eta=5.197, kappa=1.121
#   LightGBM weighted fold 1/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 2/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 3/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 4/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 5/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
# [I 2026-07-08 01:14:23,019] Trial 2 finished with values: [0.7915421325751404, 0.78125, 0.7694048789382301] and parameters: {'beta': 0.34850167300919677, 'eta': 5.197056874649611, 'kappa': 1.1213380140918507}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=4.248, eta=0.1235, kappa=1.564
#   LightGBM weighted fold 1/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   LightGBM weighted fold 2/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   LightGBM weighted fold 3/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   LightGBM weighted fold 4/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   LightGBM weighted fold 5/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
# [I 2026-07-08 01:14:31,279] Trial 3 finished with values: [0.7357050856234784, 0.8125, 0.7592247611066355] and parameters: {'beta': 4.248435466776273, 'eta': 0.12350696577481468, 'kappa': 1.5638918225943934}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=4.995, eta=1.274, kappa=0.6182
#   LightGBM weighted fold 1/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   LightGBM weighted fold 2/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   LightGBM weighted fold 3/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   LightGBM weighted fold 4/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   LightGBM weighted fold 5/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
# [I 2026-07-08 01:14:39,112] Trial 4 finished with values: [0.7625167619509297, 0.78125, 0.755090527630502] and parameters: {'beta': 4.99465584480253, 'eta': 1.274034664069657, 'kappa': 0.6181899606485208}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=1.1, eta=1.825, kappa=1.03
#   LightGBM weighted fold 1/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   LightGBM weighted fold 2/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   LightGBM weighted fold 3/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   LightGBM weighted fold 4/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   LightGBM weighted fold 5/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
# [I 2026-07-08 01:14:46,810] Trial 5 finished with values: [0.7698791981397027, 0.78125, 0.7687802296787535] and parameters: {'beta': 1.100427059120603, 'eta': 1.8254534577572263, 'kappa': 1.0297077179586855}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.592, eta=1.747, kappa=1.134
#   LightGBM weighted fold 1/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   LightGBM weighted fold 2/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   LightGBM weighted fold 3/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   LightGBM weighted fold 4/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   LightGBM weighted fold 5/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
# [I 2026-07-08 01:14:54,854] Trial 6 finished with values: [0.7357050856234784, 0.84375, 0.7620201045904744] and parameters: {'beta': 2.591670111852695, 'eta': 1.7473748411882515, 'kappa': 1.1342234736668555}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=0.837, eta=1.753, kappa=0.8396
#   LightGBM weighted fold 1/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   LightGBM weighted fold 2/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   LightGBM weighted fold 3/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   LightGBM weighted fold 4/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   LightGBM weighted fold 5/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
# [I 2026-07-08 01:15:02,697] Trial 7 finished with values: [0.7625994859530509, 0.78125, 0.765877581558361] and parameters: {'beta': 0.836963163912251, 'eta': 1.752867891211309, 'kappa': 0.8396342119524302}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.736, eta=4.711, kappa=0.6396
#   LightGBM weighted fold 1/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   LightGBM weighted fold 2/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   LightGBM weighted fold 3/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   LightGBM weighted fold 4/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   LightGBM weighted fold 5/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
# [I 2026-07-08 01:15:10,385] Trial 8 finished with values: [0.7697964741375817, 0.75, 0.7673433102235235] and parameters: {'beta': 2.7364199053022156, 'eta': 4.711055768358081, 'kappa': 0.6396085385900317}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.085, eta=3.554, kappa=0.4557
#   LightGBM weighted fold 1/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   LightGBM weighted fold 2/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   LightGBM weighted fold 3/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   LightGBM weighted fold 4/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   LightGBM weighted fold 5/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
# [I 2026-07-08 01:15:18,080] Trial 9 finished with values: [0.7698791981397027, 0.78125, 0.7714737637761316] and parameters: {'beta': 3.0854066304816694, 'eta': 3.5544874131722546, 'kappa': 0.4557404952639973}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.645, eta=1.023, kappa=0.4781
#   LightGBM weighted fold 1/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   LightGBM weighted fold 2/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   LightGBM weighted fold 3/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   LightGBM weighted fold 4/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   LightGBM weighted fold 5/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
# [I 2026-07-08 01:15:25,691] Trial 10 finished with values: [0.7620278630983943, 0.78125, 0.758254578732118] and parameters: {'beta': 3.64526911140863, 'eta': 1.0231447421237492, 'kappa': 0.47806191158233546}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=5.693, eta=5.794, kappa=1.37
#   LightGBM weighted fold 1/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   LightGBM weighted fold 2/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   LightGBM weighted fold 3/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   LightGBM weighted fold 4/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   LightGBM weighted fold 5/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
# [I 2026-07-08 01:15:33,733] Trial 11 finished with values: [0.7357050856234784, 0.84375, 0.7635685896041373] and parameters: {'beta': 5.69331322352, 'eta': 5.793792198447356, 'kappa': 1.3700768177397535}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=1.828, eta=0.586, kappa=1.221
#   LightGBM weighted fold 1/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   LightGBM weighted fold 2/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   LightGBM weighted fold 3/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   LightGBM weighted fold 4/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   LightGBM weighted fold 5/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
# [I 2026-07-08 01:15:41,764] Trial 12 finished with values: [0.7620278630983943, 0.8125, 0.7654318435001614] and parameters: {'beta': 1.8276826150402241, 'eta': 0.5860326840383032, 'kappa': 1.2210796318145885}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.641, eta=0.7322, kappa=0.9942
#   LightGBM weighted fold 1/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   LightGBM weighted fold 2/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   LightGBM weighted fold 3/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   LightGBM weighted fold 4/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   LightGBM weighted fold 5/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
# [I 2026-07-08 01:15:49,617] Trial 13 finished with values: [0.7620278630983943, 0.78125, 0.7604484162491556] and parameters: {'beta': 2.640914962437608, 'eta': 0.732229409068673, 'kappa': 0.9942122921335244}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=0.2063, eta=5.456, kappa=0.7105
#   LightGBM weighted fold 1/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   LightGBM weighted fold 2/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   LightGBM weighted fold 3/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   LightGBM weighted fold 4/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   LightGBM weighted fold 5/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
# [I 2026-07-08 01:15:57,529] Trial 14 finished with values: [0.7683041331393181, 0.78125, 0.7719533861088129] and parameters: {'beta': 0.20633112669131037, 'eta': 5.455922412472693, 'kappa': 0.7105359779200203}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.975, eta=1.87, kappa=1.024
#   LightGBM weighted fold 1/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   LightGBM weighted fold 2/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   LightGBM weighted fold 3/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   LightGBM weighted fold 4/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   LightGBM weighted fold 5/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
# [I 2026-07-08 01:16:05,646] Trial 15 finished with values: [0.7625167619509297, 0.78125, 0.766038348647052] and parameters: {'beta': 3.975133706123892, 'eta': 1.8702664565364657, 'kappa': 1.024081625413373}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.28, eta=1.109, kappa=1.564
#   LightGBM weighted fold 1/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   LightGBM weighted fold 2/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   LightGBM weighted fold 3/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   LightGBM weighted fold 4/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   LightGBM weighted fold 5/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
# [I 2026-07-08 01:16:13,713] Trial 16 finished with values: [0.7625167619509297, 0.78125, 0.7626240014081415] and parameters: {'beta': 3.280261676059678, 'eta': 1.1091267331531622, 'kappa': 1.5635015533174705}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=4.651, eta=5.637, kappa=1.474
#   LightGBM weighted fold 1/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   LightGBM weighted fold 2/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   LightGBM weighted fold 3/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   LightGBM weighted fold 4/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   LightGBM weighted fold 5/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
# [I 2026-07-08 01:16:21,898] Trial 17 finished with values: [0.7625994859530509, 0.78125, 0.7686571439309174] and parameters: {'beta': 4.650796940166687, 'eta': 5.6369936493851345, 'kappa': 1.4737928205131787}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.587, eta=5.531, kappa=0.5062
#   LightGBM weighted fold 1/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   LightGBM weighted fold 2/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   LightGBM weighted fold 3/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   LightGBM weighted fold 4/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   LightGBM weighted fold 5/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
# [I 2026-07-08 01:16:29,405] Trial 18 finished with values: [0.7625994859530509, 0.78125, 0.7693651762780535] and parameters: {'beta': 3.587399872866511, 'eta': 5.531245410138701, 'kappa': 0.5061910024623034}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=1.176, eta=0.2714, kappa=0.7904
#   LightGBM weighted fold 1/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   LightGBM weighted fold 2/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   LightGBM weighted fold 3/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   LightGBM weighted fold 4/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   LightGBM weighted fold 5/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
# [I 2026-07-08 01:16:37,350] Trial 19 finished with values: [0.7361939844760139, 0.84375, 0.7669229349480416] and parameters: {'beta': 1.1758971745148712, 'eta': 0.2713637334632284, 'kappa': 0.7903963969159173}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.332, eta=1.628, kappa=1.394
#   LightGBM weighted fold 1/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   LightGBM weighted fold 2/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   LightGBM weighted fold 3/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   LightGBM weighted fold 4/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   LightGBM weighted fold 5/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
# [I 2026-07-08 01:16:45,339] Trial 20 finished with values: [0.7620278630983943, 0.8125, 0.7628447121330963] and parameters: {'beta': 2.332063738136892, 'eta': 1.6280941906433755, 'kappa': 1.3944850109823155}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.141, eta=1.686, kappa=1.051
#   LightGBM weighted fold 1/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   LightGBM weighted fold 2/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   LightGBM weighted fold 3/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   LightGBM weighted fold 4/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   LightGBM weighted fold 5/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
# [I 2026-07-08 01:16:53,218] Trial 21 finished with values: [0.7625994859530509, 0.78125, 0.7599745330929564] and parameters: {'beta': 2.1405199601615355, 'eta': 1.6856070581242846, 'kappa': 1.0512352997898984}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=0.8455, eta=4.813, kappa=0.4895
#   LightGBM weighted fold 1/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   LightGBM weighted fold 2/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   LightGBM weighted fold 3/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   LightGBM weighted fold 4/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   LightGBM weighted fold 5/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
# [I 2026-07-08 01:17:00,866] Trial 22 finished with values: [0.7697964741375816, 0.75, 0.7675591137115647] and parameters: {'beta': 0.8455453498485759, 'eta': 4.813181884524238, 'kappa': 0.489460772415725}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=5.921, eta=4.633, kappa=0.6385
#   LightGBM weighted fold 1/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   LightGBM weighted fold 2/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   LightGBM weighted fold 3/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   LightGBM weighted fold 4/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   LightGBM weighted fold 5/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
# [I 2026-07-08 01:17:08,634] Trial 23 finished with values: [0.7625167619509297, 0.78125, 0.7592666306738048] and parameters: {'beta': 5.921321619603104, 'eta': 4.633468615779945, 'kappa': 0.638458817841007}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=0.03313, eta=4.893, kappa=1.248
#   LightGBM weighted fold 1/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   LightGBM weighted fold 2/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   LightGBM weighted fold 3/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   LightGBM weighted fold 4/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   LightGBM weighted fold 5/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
# [I 2026-07-08 01:17:16,451] Trial 24 finished with values: [0.7915421325751404, 0.78125, 0.7663391757714654] and parameters: {'beta': 0.033132702741614395, 'eta': 4.892768570729005, 'kappa': 1.2482288126171406}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=4.374, eta=4.628, kappa=0.4889
#   LightGBM weighted fold 1/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   LightGBM weighted fold 2/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   LightGBM weighted fold 3/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   LightGBM weighted fold 4/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   LightGBM weighted fold 5/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
# [I 2026-07-08 01:17:23,937] Trial 25 finished with values: [0.7625167619509297, 0.78125, 0.766032393528363] and parameters: {'beta': 4.374043008245923, 'eta': 4.627622080115675, 'kappa': 0.48885358208090846}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=2.151, eta=0.6952, kappa=1.436
#   LightGBM weighted fold 1/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   LightGBM weighted fold 2/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   LightGBM weighted fold 3/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   LightGBM weighted fold 4/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   LightGBM weighted fold 5/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
# [I 2026-07-08 01:17:31,965] Trial 26 finished with values: [0.7361112604738927, 0.78125, 0.7627825311570874] and parameters: {'beta': 2.1507943712656354, 'eta': 0.6952143571507783, 'kappa': 1.4357241110507124}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.74, eta=1.985, kappa=0.4763
#   LightGBM weighted fold 1/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   LightGBM weighted fold 2/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   LightGBM weighted fold 3/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   LightGBM weighted fold 4/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   LightGBM weighted fold 5/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
# [I 2026-07-08 01:17:39,600] Trial 27 finished with values: [0.7620278630983943, 0.8125, 0.7625011268534405] and parameters: {'beta': 3.7397887609653475, 'eta': 1.9853881491158951, 'kappa': 0.4762700203432284}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=1.866, eta=1.951, kappa=1.276
#   LightGBM weighted fold 1/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   LightGBM weighted fold 2/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   LightGBM weighted fold 3/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   LightGBM weighted fold 4/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   LightGBM weighted fold 5/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
# [I 2026-07-08 01:17:47,669] Trial 28 finished with values: [0.7624340379488088, 0.75, 0.761265139798607] and parameters: {'beta': 1.8658939302939732, 'eta': 1.9510999321604823, 'kappa': 1.275527414005677}.
#
# [BASE | LightGBM] optuna: amount_aware, beta=3.825, eta=5.323, kappa=0.9667
#   LightGBM weighted fold 1/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   LightGBM weighted fold 2/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   LightGBM weighted fold 3/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   LightGBM weighted fold 4/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
# [I 2026-07-08 01:17:56,023] A new study created in memory with name: amount_loss_v2_XGBoost
#   LightGBM weighted fold 5/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
# [I 2026-07-08 01:17:56,015] Trial 29 finished with values: [0.7698791981397025, 0.8125, 0.7710285332389715] and parameters: {'beta': 3.8253448281312785, 'eta': 5.323276455457959, 'kappa': 0.9666579101943392}.
#   0%|          | 0/30 [00:00<?, ?it/s]
# [BASE | XGBoost] optuna: amount_aware, beta=2.247, eta=5.704, kappa=1.278
#   XGBoost weighted fold 1/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   XGBoost weighted fold 2/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   XGBoost weighted fold 3/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   XGBoost weighted fold 4/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
#   XGBoost weighted fold 5/5 完成 (beta=2.247, eta=5.704, kappa=1.278)
# [I 2026-07-08 01:18:01,278] Trial 0 finished with values: [0.7610244209526663, 0.8125, 0.7532252508345361] and parameters: {'beta': 2.247240713084175, 'eta': 5.704285838459497, 'kappa': 1.2783927301736862}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.592, eta=0.9361, kappa=0.5872
#   XGBoost weighted fold 1/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   XGBoost weighted fold 2/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   XGBoost weighted fold 3/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   XGBoost weighted fold 4/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
#   XGBoost weighted fold 5/5 完成 (beta=3.592, eta=0.9361, kappa=0.5872)
# [I 2026-07-08 01:18:06,501] Trial 1 finished with values: [0.7625994859530507, 0.8125, 0.7541710243487275] and parameters: {'beta': 3.5919509051822196, 'eta': 0.9361118426546191, 'kappa': 0.5871934244034432}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=0.3485, eta=5.197, kappa=1.121
#   XGBoost weighted fold 1/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   XGBoost weighted fold 2/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   XGBoost weighted fold 3/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   XGBoost weighted fold 4/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   XGBoost weighted fold 5/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
# [I 2026-07-08 01:18:11,696] Trial 2 finished with values: [0.7610244209526663, 0.8125, 0.7554355348472589] and parameters: {'beta': 0.34850167300919677, 'eta': 5.197056874649611, 'kappa': 1.1213380140918507}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=4.248, eta=0.1235, kappa=1.564
#   XGBoost weighted fold 1/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 2/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 3/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 4/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 5/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
# [I 2026-07-08 01:18:16,955] Trial 3 finished with values: [0.7625994859530507, 0.84375, 0.7603048416616863] and parameters: {'beta': 4.248435466776273, 'eta': 0.12350696577481468, 'kappa': 1.5638918225943934}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=4.995, eta=1.274, kappa=0.6182
#   XGBoost weighted fold 1/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   XGBoost weighted fold 2/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   XGBoost weighted fold 3/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   XGBoost weighted fold 4/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
#   XGBoost weighted fold 5/5 完成 (beta=4.995, eta=1.274, kappa=0.6182)
# [I 2026-07-08 01:18:22,213] Trial 4 finished with values: [0.7625994859530507, 0.84375, 0.7552895720627081] and parameters: {'beta': 4.99465584480253, 'eta': 1.274034664069657, 'kappa': 0.6181899606485208}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=1.1, eta=1.825, kappa=1.03
#   XGBoost weighted fold 1/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   XGBoost weighted fold 2/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   XGBoost weighted fold 3/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   XGBoost weighted fold 4/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
#   XGBoost weighted fold 5/5 完成 (beta=1.1, eta=1.825, kappa=1.03)
# [I 2026-07-08 01:18:27,318] Trial 5 finished with values: [0.7625994859530507, 0.8125, 0.7587394369441471] and parameters: {'beta': 1.100427059120603, 'eta': 1.8254534577572263, 'kappa': 1.0297077179586855}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.592, eta=1.747, kappa=1.134
#   XGBoost weighted fold 1/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   XGBoost weighted fold 2/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   XGBoost weighted fold 3/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   XGBoost weighted fold 4/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
#   XGBoost weighted fold 5/5 完成 (beta=2.592, eta=1.747, kappa=1.134)
# [I 2026-07-08 01:18:32,559] Trial 6 finished with values: [0.7361939844760139, 0.8125, 0.7578024912857505] and parameters: {'beta': 2.591670111852695, 'eta': 1.7473748411882515, 'kappa': 1.1342234736668555}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=0.837, eta=1.753, kappa=0.8396
#   XGBoost weighted fold 1/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   XGBoost weighted fold 2/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   XGBoost weighted fold 3/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   XGBoost weighted fold 4/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
#   XGBoost weighted fold 5/5 完成 (beta=0.837, eta=1.753, kappa=0.8396)
# [I 2026-07-08 01:18:37,819] Trial 7 finished with values: [0.7610244209526663, 0.84375, 0.7577140459471025] and parameters: {'beta': 0.836963163912251, 'eta': 1.752867891211309, 'kappa': 0.8396342119524302}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.736, eta=4.711, kappa=0.6396
#   XGBoost weighted fold 1/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   XGBoost weighted fold 2/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   XGBoost weighted fold 3/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   XGBoost weighted fold 4/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
#   XGBoost weighted fold 5/5 完成 (beta=2.736, eta=4.711, kappa=0.6396)
# [I 2026-07-08 01:18:42,986] Trial 8 finished with values: [0.7610244209526663, 0.8125, 0.7510638318460839] and parameters: {'beta': 2.7364199053022156, 'eta': 4.711055768358081, 'kappa': 0.6396085385900317}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.085, eta=3.554, kappa=0.4557
#   XGBoost weighted fold 1/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   XGBoost weighted fold 2/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   XGBoost weighted fold 3/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   XGBoost weighted fold 4/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
#   XGBoost weighted fold 5/5 完成 (beta=3.085, eta=3.554, kappa=0.4557)
# [I 2026-07-08 01:18:48,215] Trial 9 finished with values: [0.7609416969505453, 0.78125, 0.7477574089276733] and parameters: {'beta': 3.0854066304816694, 'eta': 3.5544874131722546, 'kappa': 0.4557404952639973}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.645, eta=1.023, kappa=0.4781
#   XGBoost weighted fold 1/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   XGBoost weighted fold 2/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   XGBoost weighted fold 3/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   XGBoost weighted fold 4/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
#   XGBoost weighted fold 5/5 完成 (beta=3.645, eta=1.023, kappa=0.4781)
# [I 2026-07-08 01:18:53,128] Trial 10 finished with values: [0.7625994859530507, 0.8125, 0.7542084829579161] and parameters: {'beta': 3.64526911140863, 'eta': 1.0231447421237492, 'kappa': 0.47806191158233546}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=5.693, eta=5.794, kappa=1.37
#   XGBoost weighted fold 1/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   XGBoost weighted fold 2/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   XGBoost weighted fold 3/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   XGBoost weighted fold 4/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
#   XGBoost weighted fold 5/5 完成 (beta=5.693, eta=5.794, kappa=1.37)
# [I 2026-07-08 01:18:58,361] Trial 11 finished with values: [0.7361939844760139, 0.8125, 0.7559489546496841] and parameters: {'beta': 5.69331322352, 'eta': 5.793792198447356, 'kappa': 1.3700768177397535}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=1.828, eta=0.586, kappa=1.221
#   XGBoost weighted fold 1/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   XGBoost weighted fold 2/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   XGBoost weighted fold 3/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   XGBoost weighted fold 4/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
#   XGBoost weighted fold 5/5 完成 (beta=1.828, eta=0.586, kappa=1.221)
# [I 2026-07-08 01:19:03,686] Trial 12 finished with values: [0.7625994859530507, 0.8125, 0.7554303467291353] and parameters: {'beta': 1.8276826150402241, 'eta': 0.5860326840383032, 'kappa': 1.2210796318145885}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.641, eta=0.7322, kappa=0.9942
#   XGBoost weighted fold 1/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   XGBoost weighted fold 2/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   XGBoost weighted fold 3/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   XGBoost weighted fold 4/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
#   XGBoost weighted fold 5/5 完成 (beta=2.641, eta=0.7322, kappa=0.9942)
# [I 2026-07-08 01:19:08,951] Trial 13 finished with values: [0.7361939844760139, 0.8125, 0.7578306017756453] and parameters: {'beta': 2.640914962437608, 'eta': 0.732229409068673, 'kappa': 0.9942122921335244}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=0.2063, eta=5.456, kappa=0.7105
#   XGBoost weighted fold 1/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   XGBoost weighted fold 2/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   XGBoost weighted fold 3/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   XGBoost weighted fold 4/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
#   XGBoost weighted fold 5/5 完成 (beta=0.2063, eta=5.456, kappa=0.7105)
# [I 2026-07-08 01:19:14,152] Trial 14 finished with values: [0.7610244209526663, 0.8125, 0.7648661150498902] and parameters: {'beta': 0.20633112669131037, 'eta': 5.455922412472693, 'kappa': 0.7105359779200203}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.975, eta=1.87, kappa=1.024
#   XGBoost weighted fold 1/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   XGBoost weighted fold 2/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   XGBoost weighted fold 3/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   XGBoost weighted fold 4/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
#   XGBoost weighted fold 5/5 完成 (beta=3.975, eta=1.87, kappa=1.024)
# [I 2026-07-08 01:19:19,207] Trial 15 finished with values: [0.7625994859530507, 0.8125, 0.7628830545256226] and parameters: {'beta': 3.975133706123892, 'eta': 1.8702664565364657, 'kappa': 1.024081625413373}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.28, eta=1.109, kappa=1.564
#   XGBoost weighted fold 1/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   XGBoost weighted fold 2/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   XGBoost weighted fold 3/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   XGBoost weighted fold 4/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
#   XGBoost weighted fold 5/5 完成 (beta=3.28, eta=1.109, kappa=1.564)
# [I 2026-07-08 01:19:24,566] Trial 16 finished with values: [0.7625994859530507, 0.8125, 0.7585000750210547] and parameters: {'beta': 3.280261676059678, 'eta': 1.1091267331531622, 'kappa': 1.5635015533174705}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=4.651, eta=5.637, kappa=1.474
#   XGBoost weighted fold 1/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   XGBoost weighted fold 2/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   XGBoost weighted fold 3/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   XGBoost weighted fold 4/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
#   XGBoost weighted fold 5/5 完成 (beta=4.651, eta=5.637, kappa=1.474)
# [I 2026-07-08 01:19:29,822] Trial 17 finished with values: [0.7346189194756292, 0.84375, 0.7526415955577119] and parameters: {'beta': 4.650796940166687, 'eta': 5.6369936493851345, 'kappa': 1.4737928205131787}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.587, eta=5.531, kappa=0.5062
#   XGBoost weighted fold 1/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   XGBoost weighted fold 2/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   XGBoost weighted fold 3/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   XGBoost weighted fold 4/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
#   XGBoost weighted fold 5/5 完成 (beta=3.587, eta=5.531, kappa=0.5062)
# [I 2026-07-08 01:19:34,759] Trial 18 finished with values: [0.7610244209526663, 0.8125, 0.7529691559741465] and parameters: {'beta': 3.587399872866511, 'eta': 5.531245410138701, 'kappa': 0.5061910024623034}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=1.176, eta=0.2714, kappa=0.7904
#   XGBoost weighted fold 1/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   XGBoost weighted fold 2/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   XGBoost weighted fold 3/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   XGBoost weighted fold 4/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
#   XGBoost weighted fold 5/5 完成 (beta=1.176, eta=0.2714, kappa=0.7904)
# [I 2026-07-08 01:19:39,909] Trial 19 finished with values: [0.7625994859530507, 0.84375, 0.7582634202887406] and parameters: {'beta': 1.1758971745148712, 'eta': 0.2713637334632284, 'kappa': 0.7903963969159173}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.332, eta=1.628, kappa=1.394
#   XGBoost weighted fold 1/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   XGBoost weighted fold 2/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   XGBoost weighted fold 3/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   XGBoost weighted fold 4/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
#   XGBoost weighted fold 5/5 完成 (beta=2.332, eta=1.628, kappa=1.394)
# [I 2026-07-08 01:19:45,084] Trial 20 finished with values: [0.7361939844760139, 0.8125, 0.754316338036766] and parameters: {'beta': 2.332063738136892, 'eta': 1.6280941906433755, 'kappa': 1.3944850109823155}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.141, eta=1.686, kappa=1.051
#   XGBoost weighted fold 1/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   XGBoost weighted fold 2/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   XGBoost weighted fold 3/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   XGBoost weighted fold 4/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
#   XGBoost weighted fold 5/5 完成 (beta=2.141, eta=1.686, kappa=1.051)
# [I 2026-07-08 01:19:50,337] Trial 21 finished with values: [0.7625994859530507, 0.84375, 0.7584934032520362] and parameters: {'beta': 2.1405199601615355, 'eta': 1.6856070581242846, 'kappa': 1.0512352997898984}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=0.8455, eta=4.813, kappa=0.4895
#   XGBoost weighted fold 1/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   XGBoost weighted fold 2/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   XGBoost weighted fold 3/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   XGBoost weighted fold 4/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
#   XGBoost weighted fold 5/5 完成 (beta=0.8455, eta=4.813, kappa=0.4895)
# [I 2026-07-08 01:19:54,882] Trial 22 finished with values: [0.7610244209526663, 0.8125, 0.7512224457382541] and parameters: {'beta': 0.8455453498485759, 'eta': 4.813181884524238, 'kappa': 0.489460772415725}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=5.921, eta=4.633, kappa=0.6385
#   XGBoost weighted fold 1/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   XGBoost weighted fold 2/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   XGBoost weighted fold 3/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   XGBoost weighted fold 4/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
#   XGBoost weighted fold 5/5 完成 (beta=5.921, eta=4.633, kappa=0.6385)
# [I 2026-07-08 01:20:00,015] Trial 23 finished with values: [0.7625994859530507, 0.8125, 0.7588043877683308] and parameters: {'beta': 5.921321619603104, 'eta': 4.633468615779945, 'kappa': 0.638458817841007}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=0.03313, eta=4.893, kappa=1.248
#   XGBoost weighted fold 1/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   XGBoost weighted fold 2/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   XGBoost weighted fold 3/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   XGBoost weighted fold 4/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
#   XGBoost weighted fold 5/5 完成 (beta=0.03313, eta=4.893, kappa=1.248)
# [I 2026-07-08 01:20:05,175] Trial 24 finished with values: [0.7526279347373804, 0.78125, 0.7525901555892759] and parameters: {'beta': 0.033132702741614395, 'eta': 4.892768570729005, 'kappa': 1.2482288126171406}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=4.374, eta=4.628, kappa=0.4889
#   XGBoost weighted fold 1/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   XGBoost weighted fold 2/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   XGBoost weighted fold 3/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   XGBoost weighted fold 4/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
#   XGBoost weighted fold 5/5 完成 (beta=4.374, eta=4.628, kappa=0.4889)
# [I 2026-07-08 01:20:10,111] Trial 25 finished with values: [0.7625994859530507, 0.8125, 0.7523088393070783] and parameters: {'beta': 4.374043008245923, 'eta': 4.627622080115675, 'kappa': 0.48885358208090846}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=2.151, eta=0.6952, kappa=1.436
#   XGBoost weighted fold 1/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   XGBoost weighted fold 2/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   XGBoost weighted fold 3/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   XGBoost weighted fold 4/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
#   XGBoost weighted fold 5/5 完成 (beta=2.151, eta=0.6952, kappa=1.436)
# [I 2026-07-08 01:20:15,556] Trial 26 finished with values: [0.7361939844760139, 0.8125, 0.7613821458492172] and parameters: {'beta': 2.1507943712656354, 'eta': 0.6952143571507783, 'kappa': 1.4357241110507124}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.74, eta=1.985, kappa=0.4763
#   XGBoost weighted fold 1/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   XGBoost weighted fold 2/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   XGBoost weighted fold 3/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   XGBoost weighted fold 4/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
#   XGBoost weighted fold 5/5 完成 (beta=3.74, eta=1.985, kappa=0.4763)
# [I 2026-07-08 01:20:20,618] Trial 27 finished with values: [0.7625994859530507, 0.8125, 0.7545229511137297] and parameters: {'beta': 3.7397887609653475, 'eta': 1.9853881491158951, 'kappa': 0.4762700203432284}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=1.866, eta=1.951, kappa=1.276
#   XGBoost weighted fold 1/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   XGBoost weighted fold 2/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   XGBoost weighted fold 3/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   XGBoost weighted fold 4/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
#   XGBoost weighted fold 5/5 完成 (beta=1.866, eta=1.951, kappa=1.276)
# [I 2026-07-08 01:20:25,934] Trial 28 finished with values: [0.7361939844760139, 0.84375, 0.7566251849404877] and parameters: {'beta': 1.8658939302939732, 'eta': 1.9510999321604823, 'kappa': 1.275527414005677}.
#
# [BASE | XGBoost] optuna: amount_aware, beta=3.825, eta=5.323, kappa=0.9667
#   XGBoost weighted fold 1/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   XGBoost weighted fold 2/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   XGBoost weighted fold 3/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   XGBoost weighted fold 4/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
#   XGBoost weighted fold 5/5 完成 (beta=3.825, eta=5.323, kappa=0.9667)
# [I 2026-07-08 01:20:31,052] Trial 29 finished with values: [0.7610244209526663, 0.8125, 0.7545177250669078] and parameters: {'beta': 3.8253448281312785, 'eta': 5.323276455457959, 'kappa': 0.9666579101943392}.
#      特征组        模型       实验        β        η        κ   金额召回@K   漏报金额@K   小额召回@K
# 0   BASE  LightGBM  原始 BASE  0.00000  0.00000  1.00000  0.76980  2782.79  0.81250
# 1   BASE  LightGBM  中性 BASE  0.00000  0.00000  1.00000  0.76971  2783.79  0.78125
# 2   BASE  LightGBM   optuna  2.24724  5.70429  1.27839  0.76931  2788.70  0.81250
# 3   BASE  LightGBM   optuna  3.59195  0.93611  0.58719  0.76252  2870.79  0.78125
# 4   BASE  LightGBM   optuna  0.34850  5.19706  1.12134  0.79154  2519.92  0.78125
# ..   ...       ...      ...      ...      ...      ...      ...      ...      ...
# 59  BASE   XGBoost   optuna  4.37404  4.62762  0.48885  0.76260  2869.79  0.81250
# 60  BASE   XGBoost   optuna  2.15079  0.69521  1.43572  0.73619  3188.99  0.81250
# 61  BASE   XGBoost   optuna  3.73979  1.98539  0.47627  0.76260  2869.79  0.81250
# 62  BASE   XGBoost   optuna  1.86589  1.95110  1.27553  0.73619  3188.99  0.84375
# 63  BASE   XGBoost   optuna  3.82534  5.32328  0.96666  0.76102  2888.83  0.81250
#
# [64 rows x 9 columns]

# %% [markdown]
# ## 8. 合并候选并只用 calibration 选最终参数
#
# 粗网格、精细网格和 Optuna 候选统一放入 calibration Pareto 比较。最终参数保存后，才读取其 evaluation 指标并进入第二阶段。

# %%
# §8 prep：Pareto 与最终选参
def pareto_front(frame):
    frame = frame.reset_index(drop=True).copy()
    values = frame[['MissedAmount_cal_atK', 'MicroFN_cal_atK', 'FN_cal_atK']].to_numpy(float)
    keep = np.ones(len(frame), dtype=bool)
    for i in range(len(frame)):
        dominated = np.all(values <= values[i], axis=1) & np.any(values < values[i], axis=1)
        dominated[i] = False
        keep[i] = not dominated.any()
    return frame[keep].copy()


def select_final_params(coarse, fine, optuna_frame):
    frames = [x for x in (coarse, fine, optuna_frame) if not x.empty]
    candidates = pd.concat(frames, ignore_index=True)
    candidates = candidates[candidates.loss_kind == 'amount_aware'].copy()
    selected, fronts = {}, []
    for model_name in MODELS:
        front = pareto_front(candidates[candidates.model == model_name])
        front['pareto'] = True
        fronts.append(front)
        best = best_on_cal(front, model_name)
        selected[model_name] = {'beta': float(best.beta), 'eta': float(best.eta),
                                'kappa': float(best.kappa), 'source': str(best.experiment)}
    return selected, pd.concat(fronts, ignore_index=True)

# %%
# §8 exec：最终 calibration 选参
if not coarse_results.empty:
    FINAL_SELECTED_PARAMS, final_pareto = select_final_params(
        coarse_results, fine_results, optuna_results)
    (OUT_AMOUNT_LOSS / 'final_selected_params.json').write_text(
        json.dumps(FINAL_SELECTED_PARAMS, ensure_ascii=False, indent=2), encoding='utf-8')
    final_pareto.to_csv(OUT_AMOUNT_LOSS / 'final_calibration_pareto.csv', index=False)
    print(json.dumps(FINAL_SELECTED_PARAMS, ensure_ascii=False, indent=2))
    pareto_display = with_base_rows(final_pareto, coarse_results)
    display(compact_business_table(pareto_display, 'cal').round(5))
else:
    FINAL_SELECTED_PARAMS, final_pareto = {}, pd.DataFrame()
# Out:
# {
#   "LightGBM": {
#     "beta": 0.34850167300919677,
#     "eta": 5.197056874649611,
#     "kappa": 1.1213380140918507,
#     "source": "optuna"
#   },
#   "XGBoost": {
#     "beta": 4.248435466776273,
#     "eta": 0.12350696577481468,
#     "kappa": 1.5638918225943934,
#     "source": "optuna"
#   }
# }
#      特征组        模型          实验        β        η        κ   金额召回@K   漏报金额@K   小额召回@K
# 0   BASE  LightGBM     原始 BASE  0.00000  0.00000  1.00000  0.76980  2782.79  0.81250
# 1   BASE  LightGBM     中性 BASE  0.00000  0.00000  1.00000  0.76971  2783.79  0.78125
# 2   BASE  LightGBM   exp1_beta  1.00000  0.00000  1.00000  0.73619  3188.99  0.84375
# 3   BASE  LightGBM    exp2_eta  0.25000  1.00000  1.00000  0.76988  2781.79  0.81250
# 4   BASE  LightGBM  exp3_kappa  0.25000  2.00000  1.25000  0.76988  2781.79  0.81250
# 5   BASE  LightGBM   fine_beta  0.31250  2.00000  1.00000  0.76988  2781.79  0.81250
# 6   BASE  LightGBM   fine_beta  0.37500  2.00000  1.00000  0.76988  2781.79  0.81250
# 7   BASE  LightGBM    fine_eta  0.25000  1.00000  1.00000  0.76988  2781.79  0.81250
# 8   BASE  LightGBM    fine_eta  0.25000  2.50000  1.00000  0.76988  2781.79  0.81250
# 9   BASE  LightGBM      optuna  0.34850  5.19706  1.12134  0.79154  2519.92  0.78125
# 10  BASE  LightGBM      optuna  1.17590  0.27136  0.79040  0.73619  3188.99  0.84375
# 11  BASE  LightGBM      optuna  0.03313  4.89277  1.24823  0.79154  2519.92  0.78125
# 12  BASE  LightGBM      optuna  3.82534  5.32328  0.96666  0.76988  2781.79  0.81250
# 13  BASE   XGBoost     原始 BASE  0.00000  0.00000  1.00000  0.76260  2869.79  0.84375
# 14  BASE   XGBoost     中性 BASE  0.00000  0.00000  1.00000  0.73619  3188.99  0.81250
# 15  BASE   XGBoost   exp1_beta  2.00000  0.00000  1.00000  0.76260  2869.79  0.84375
# 16  BASE   XGBoost   exp1_beta  4.00000  0.00000  1.00000  0.76260  2869.79  0.84375
# 17  BASE   XGBoost    exp2_eta  4.00000  0.25000  1.00000  0.76260  2869.79  0.84375
# 18  BASE   XGBoost    exp2_eta  4.00000  1.00000  1.00000  0.76260  2869.79  0.84375
# 19  BASE   XGBoost  exp3_kappa  4.00000  1.00000  0.50000  0.76260  2869.79  0.84375
# 20  BASE   XGBoost  exp3_kappa  4.00000  1.00000  1.00000  0.76260  2869.79  0.84375
# 21  BASE   XGBoost   fine_beta  4.00000  1.00000  1.00000  0.76260  2869.79  0.84375
# 22  BASE   XGBoost    fine_eta  4.00000  1.00000  1.00000  0.76260  2869.79  0.84375
# 23  BASE   XGBoost  fine_kappa  4.00000  1.00000  0.80000  0.76260  2869.79  0.84375
# 24  BASE   XGBoost  fine_kappa  4.00000  1.00000  0.90000  0.76260  2869.79  0.84375
# 25  BASE   XGBoost  fine_kappa  4.00000  1.00000  1.00000  0.76260  2869.79  0.84375
# 26  BASE   XGBoost  fine_kappa  4.00000  1.00000  1.10000  0.76260  2869.79  0.84375
# 27  BASE   XGBoost      optuna  4.24844  0.12351  1.56389  0.76260  2869.79  0.84375
# 28  BASE   XGBoost      optuna  4.99466  1.27403  0.61819  0.76260  2869.79  0.84375
# 29  BASE   XGBoost      optuna  1.17590  0.27136  0.79040  0.76260  2869.79  0.84375
# 30  BASE   XGBoost      optuna  2.14052  1.68561  1.05124  0.76260  2869.79  0.84375

# %% [markdown]
# ## 9. 第二阶段：BASE / §7–8 胜者 × neutral / 新损失
#
# 每个特征组同时保留 builtin 锚点、neutral 因果 baseline 和选中的新损失。参数由 BASE calibration 选出；第二阶段 evaluation 不再参与选参。

# %%
# §9 prep：第二阶段迁移
def load_final_params():
    path = OUT_AMOUNT_LOSS / 'final_selected_params.json'
    if not path.is_file():
        raise FileNotFoundError('请先完成 §8 最终选参')
    return json.loads(path.read_text(encoding='utf-8'))


def run_stage2(data):
    selected = load_final_params()
    groups = {'BASE': BASE_FEATURES, 'ABLATION_WINNER': WINNER_FEATURES}
    rows = []
    for group, features in groups.items():
        for model_name in MODELS:
            anchor = run_config(model_name, data, features, group, 'stage2_builtin', 'builtin')
            rows.append(anchor)
            rate = anchor['alert_rate']
            rows.append(run_config(model_name, data, features, group, 'stage2_neutral',
                                   'amount_aware', 0, 0, 1, rate))
            p = selected[model_name]
            rows.append(run_config(model_name, data, features, group, 'stage2_selected',
                                   'amount_aware', p['beta'], p['eta'], p['kappa'], rate))
            pd.DataFrame(rows).to_csv(OUT_STAGE2 / 'stage2_checkpoint.csv', index=False)
    result = pd.DataFrame(rows)
    result.to_csv(OUT_STAGE2 / 'stage2_results.csv', index=False)
    return result

# %%
# §9 exec：第二阶段
if RUN_STAGE2:
    stage2_results = run_stage2(df_all)
else:
    path = OUT_STAGE2 / 'stage2_results.csv'
    stage2_results = pd.read_csv(path) if path.is_file() else pd.DataFrame()
    print('RUN_STAGE2=False；已有第二阶段行数:', len(stage2_results))
if not stage2_results.empty:
    stage2_display = with_base_rows(stage2_results, stage2_results)
    print('分类核心表（evaluation）')
    display(compact_classification_table(stage2_display, 'eval').round(5))
    print('业务核心表（evaluation）')
    display(compact_business_table(stage2_display, 'eval').round(5))
# Out:
# [BASE | LightGBM] stage2_builtin: builtin, beta=0, eta=0, kappa=1
#   LightGBM builtin fold 1/5 完成
#   LightGBM builtin fold 2/5 完成
#   LightGBM builtin fold 3/5 完成
#   LightGBM builtin fold 4/5 完成
#   LightGBM builtin fold 5/5 完成
#
# [BASE | LightGBM] stage2_neutral: amount_aware, beta=0, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [BASE | LightGBM] stage2_selected: amount_aware, beta=0.3485, eta=5.197, kappa=1.121
#   LightGBM weighted fold 1/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 2/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 3/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 4/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 5/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#
# [BASE | XGBoost] stage2_builtin: builtin, beta=0, eta=0, kappa=1
#   XGBoost builtin fold 1/5 完成
#   XGBoost builtin fold 2/5 完成
#   XGBoost builtin fold 3/5 完成
#   XGBoost builtin fold 4/5 完成
#   XGBoost builtin fold 5/5 完成
#
# [BASE | XGBoost] stage2_neutral: amount_aware, beta=0, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [BASE | XGBoost] stage2_selected: amount_aware, beta=4.248, eta=0.1235, kappa=1.564
#   XGBoost weighted fold 1/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 2/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 3/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 4/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 5/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#
# [ABLATION_WINNER | LightGBM] stage2_builtin: builtin, beta=0, eta=0, kappa=1
#   LightGBM builtin fold 1/5 完成
#   LightGBM builtin fold 2/5 完成
#   LightGBM builtin fold 3/5 完成
#   LightGBM builtin fold 4/5 完成
#   LightGBM builtin fold 5/5 完成
#
# [ABLATION_WINNER | LightGBM] stage2_neutral: amount_aware, beta=0, eta=0, kappa=1
#   LightGBM weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   LightGBM weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [ABLATION_WINNER | LightGBM] stage2_selected: amount_aware, beta=0.3485, eta=5.197, kappa=1.121
#   LightGBM weighted fold 1/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 2/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 3/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 4/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#   LightGBM weighted fold 5/5 完成 (beta=0.3485, eta=5.197, kappa=1.121)
#
# [ABLATION_WINNER | XGBoost] stage2_builtin: builtin, beta=0, eta=0, kappa=1
#   XGBoost builtin fold 1/5 完成
#   XGBoost builtin fold 2/5 完成
#   XGBoost builtin fold 3/5 完成
#   XGBoost builtin fold 4/5 完成
#   XGBoost builtin fold 5/5 完成
#
# [ABLATION_WINNER | XGBoost] stage2_neutral: amount_aware, beta=0, eta=0, kappa=1
#   XGBoost weighted fold 1/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 2/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 3/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 4/5 完成 (beta=0, eta=0, kappa=1)
#   XGBoost weighted fold 5/5 完成 (beta=0, eta=0, kappa=1)
#
# [ABLATION_WINNER | XGBoost] stage2_selected: amount_aware, beta=4.248, eta=0.1235, kappa=1.564
#   XGBoost weighted fold 1/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 2/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 3/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 4/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
#   XGBoost weighted fold 5/5 完成 (beta=4.248, eta=0.1235, kappa=1.564)
# 分类核心表（evaluation）
#                 特征组        模型       实验            损失        β        η        κ   AUC-PR     F1@K  Precision@K  Recall@K  FP@K  FN@K
# 0   ABLATION_WINNER  LightGBM  原始 BASE       builtin  0.00000  0.00000  1.00000  0.77073  0.77447      0.86667   0.70000    28    78
# 1   ABLATION_WINNER  LightGBM  中性 BASE  amount_aware  0.00000  0.00000  1.00000  0.77129  0.78298      0.87619   0.70769    26    76
# 2   ABLATION_WINNER  LightGBM     选中参数  amount_aware  0.34850  5.19706  1.12134  0.76873  0.76170      0.85238   0.68846    31    81
# 3   ABLATION_WINNER   XGBoost  原始 BASE       builtin  0.00000  0.00000  1.00000  0.74994  0.74790      0.82407   0.68462    38    82
# 4   ABLATION_WINNER   XGBoost  中性 BASE  amount_aware  0.00000  0.00000  1.00000  0.74605  0.73950      0.81481   0.67692    40    84
# 5   ABLATION_WINNER   XGBoost     选中参数  amount_aware  4.24844  0.12351  1.56389  0.72951  0.70168      0.77315   0.64231    49    93
# 6              BASE  LightGBM  原始 BASE       builtin  0.00000  0.00000  1.00000  0.75902  0.75922      0.87065   0.67308    26    85
# 7              BASE  LightGBM  中性 BASE  amount_aware  0.00000  0.00000  1.00000  0.76323  0.77657      0.89055   0.68846    22    81
# 8              BASE  LightGBM     选中参数  amount_aware  0.34850  5.19706  1.12134  0.77149  0.76356      0.87562   0.67692    25    84
# 9              BASE   XGBoost  原始 BASE       builtin  0.00000  0.00000  1.00000  0.74061  0.74043      0.82857   0.66923    36    86
# 10             BASE   XGBoost  中性 BASE  amount_aware  0.00000  0.00000  1.00000  0.73768  0.72766      0.81429   0.65769    39    89
# 11             BASE   XGBoost     选中参数  amount_aware  4.24844  0.12351  1.56389  0.73085  0.71064      0.79524   0.64231    43    93
# 业务核心表（evaluation）
#                 特征组        模型       实验        β        η        κ   金额召回@K    漏报金额@K   小额召回@K
# 0   ABLATION_WINNER  LightGBM  原始 BASE  0.00000  0.00000  1.00000  0.60995  12999.18  0.68182
# 1   ABLATION_WINNER  LightGBM  中性 BASE  0.00000  0.00000  1.00000  0.61319  12891.44  0.68182
# 2   ABLATION_WINNER  LightGBM     选中参数  0.34850  5.19706  1.12134  0.61172  12940.13  0.70455
# 3   ABLATION_WINNER   XGBoost  原始 BASE  0.00000  0.00000  1.00000  0.60563  13143.40  0.68182
# 4   ABLATION_WINNER   XGBoost  中性 BASE  0.00000  0.00000  1.00000  0.58913  13693.08  0.67045
# 5   ABLATION_WINNER   XGBoost     选中参数  4.24844  0.12351  1.56389  0.57605  14128.91  0.63636
# 6              BASE  LightGBM  原始 BASE  0.00000  0.00000  1.00000  0.61870  12707.66  0.63636
# 7              BASE  LightGBM  中性 BASE  0.00000  0.00000  1.00000  0.61174  12939.46  0.65909
# 8              BASE  LightGBM     选中参数  0.34850  5.19706  1.12134  0.60312  13226.91  0.65909
# 9              BASE   XGBoost  原始 BASE  0.00000  0.00000  1.00000  0.58063  13976.56  0.69318
# 10             BASE   XGBoost  中性 BASE  0.00000  0.00000  1.00000  0.58358  13878.26  0.68182
# 11             BASE   XGBoost     选中参数  4.24844  0.12351  1.56389  0.57005  14329.04  0.64773

# %% [markdown]
# ## 10. 结果解释
#
# - `金额召回@K` 越高越好；`漏报金额@K` 越低越好，两者表达同一业务结果，因此窄表可以按阅读偏好保留其中一个，完整 CSV 两者都保存。
# - `小额召回@K` 用于检查卡测试保护，不再预设任意下降百分点。
# - Top-K 是离线排序能力评价；生产部署仍需要在独立 calibration 数据上把 K 对应回阈值并监控漂移。
# - 增加搜索精细度只能更充分探索当前损失函数族，不能保证一定超过 baseline。若最终 evaluation 仍没有 Pareto 改善，应接受“该损失设计在此数据上无增益”的结论，而不是继续扩大搜索直到撞上偶然高分。

# %% [markdown]
# # 金额变换与截尾分位数敏感性实验
#
# 本章节是在原金额感知损失 Notebook 之后追加的独立实验。原有粗网格、精细网格、Optuna 和第二阶段结果只作为背景，不会被覆盖。
#
# 研究问题非常窄：原 `log1p(Amount) + q95` 是否压缩大额差异过强？改用更温和的平方根，或将截尾点改为 q90/q99，能否在固定 Top-K 工作量下稳定减少漏报金额？
#
# 执行顺序：
#
# 1. BASE 特征、seed=42 下初筛 18 个候选/模型；
# 2. 只用 calibration 选每个模型的最终候选；
# 3. 在 BASE 和第 7/8 节胜者特征上做五种子稳定性验收；
# 4. 用 2,000 次配对分层 bootstrap 判断改善是否可靠。

# %%
# 敏感性实验参数与独立路径
import os

RUN_TRANSFORM_SCREEN = os.environ.get('RUN_TRANSFORM_SCREEN', '0') == '1'
RUN_TRANSFORM_STABILITY = os.environ.get('RUN_TRANSFORM_STABILITY', '0') == '1'
AMOUNT_TRANSFORMS = ['log', 'sqrt']
CLIP_QUANTILES = [0.90, 0.95, 0.99]
BETA_MULTIPLIERS = [0.5, 1.0, 2.0]
TRANSFORM_SEEDS = [42, 52, 62, 72, 82]
TRANSFORM_BOOTSTRAP_N = 2000
TRANSFORM_BOOTSTRAP_SEED = 20260708
ORIGINAL_SELECTED_PARAMS = {
    'LightGBM': {
        'beta': 0.3485016730091967, 'eta': 5.197056874649611,
        'kappa': 1.1213380140918507, 'source': 'prior_optuna'},
    'XGBoost': {
        'beta': 4.248435466776273, 'eta': 0.1235069657748146,
        'kappa': 1.5638918225943934, 'source': 'prior_optuna'},
}

OUT_TRANSFORM = SRC_DIR / 'output' / 'amount_transform_sensitivity'
OUT_TRANSFORM_SCREEN = OUT_TRANSFORM / '01_screen'
OUT_TRANSFORM_STABILITY = OUT_TRANSFORM / '02_stability'
TRANSFORM_OOF_CACHE = OUT_TRANSFORM / 'oof_cache'
TRANSFORM_PRED_DIR = OUT_TRANSFORM_STABILITY / 'predictions'
for _d in (OUT_TRANSFORM, OUT_TRANSFORM_SCREEN, OUT_TRANSFORM_STABILITY,
           TRANSFORM_OOF_CACHE, TRANSFORM_PRED_DIR):
    _d.mkdir(parents=True, exist_ok=True)

print('金额变换实验独立输出:', OUT_TRANSFORM)


def get_original_selected_params():
    path = OUT_AMOUNT_LOSS / 'final_selected_params.json'
    if path.is_file():
        return json.loads(path.read_text(encoding='utf-8'))
    print('提示：原结果 JSON 不在当前输出目录，使用原 Notebook 已确认的 Optuna 参数。')
    return ORIGINAL_SELECTED_PARAMS
# Out:
# 金额变换实验独立输出: /Users/jingyuhe/Desktop/credit-fraud-dealing-with-imbalanced-datasets/src/output/amount_transform_sensitivity

# %% [markdown]
# ## 11. log、sqrt 与截尾分位数解释
#
# 设原始金额为 $A\ge 0$：
#
# - `log` 使用 $\log(1+A)$。它强烈压缩长尾：金额从 10 增到 100 与从 1,000 增到 10,000，在变换空间里的增量接近。因此它稳健，但可能把极大额交易之间的差异压得太平。
# - `sqrt` 使用 $\sqrt{A}$。它仍能削弱长尾和极端值，却比 log 保留更多大额差异。例如金额放大 100 倍，平方根放大 10 倍，而 log 只增加一个固定量级。
#
# 变换后还要按 fit 子集欺诈样本分位数截尾并缩放到 $[0,1]$：
#
# $$g(A)=\operatorname{clip}\left(\frac{T(A)}{Q_q(T(A)\mid y=1,\text{fit})},0,1\right).$$
#
# - `q90`：前 10% 高变换金额都取 1，截尾最强，最稳健，但高金额内部没有区别；
# - `q95`：原设计；
# - `q99`：只有最高约 1% 被截平，更保留大额差异，也更容易受极端样本影响。
#
# β 控制金额分支强度。本实验只测试原 β 的 `0.5× / 1× / 2×`；η、κ保持原值，从而把问题限定在金额变换，而不是重新进行一次无边界调参。

# %%
# §11 prep：可配置金额变换与 fit-only 截尾状态
def _amount_transform_values(amount, amount_transform):
    amount = np.clip(np.asarray(amount, dtype=float), 0.0, None)
    if amount_transform == 'log':
        return np.log1p(amount)
    if amount_transform == 'sqrt':
        return np.sqrt(amount)
    raise ValueError(f'未知金额变换: {amount_transform}')


def fit_transform_weight_state(amount, y, beta, eta, kappa,
                               amount_transform='log', clip_quantile=0.95,
                               micro_max=1.0):
    amount = np.asarray(amount, dtype=float)
    y = np.asarray(y, dtype=int)
    if len(amount) != len(y):
        raise ValueError('amount 与 y 长度不一致')
    if beta < 0 or eta < 0 or kappa <= 0:
        raise ValueError('要求 beta>=0、eta>=0、kappa>0')
    if not 0 < clip_quantile < 1:
        raise ValueError('clip_quantile 必须位于 (0,1)')
    pos = y == 1
    n_pos, n_neg = int(pos.sum()), int((~pos).sum())
    if n_pos == 0 or n_neg == 0:
        raise ValueError('fit 子集必须同时包含正常与欺诈样本')
    transformed = _amount_transform_values(amount, amount_transform)
    clip_value = max(float(np.quantile(transformed[pos], clip_quantile)), 1e-12)
    g = np.clip(transformed / clip_value, 0.0, 1.0)
    h = (amount <= micro_max).astype(float)
    u = 1.0 + float(beta) * g + float(eta) * h
    return {
        'beta': float(beta), 'eta': float(eta), 'kappa': float(kappa),
        'amount_transform': amount_transform,
        'clip_quantile': float(clip_quantile), 'clip_value': clip_value,
        'micro_max': float(micro_max), 'u_bar_pos': float(u[pos].mean()),
        'class_ratio': float(n_neg / n_pos),
        'n_pos_fit': n_pos, 'n_neg_fit': n_neg,
    }


def transform_sensitivity_weight(amount, y, state):
    amount = np.asarray(amount, dtype=float)
    y = np.asarray(y, dtype=int)
    transformed = _amount_transform_values(amount, state['amount_transform'])
    g = np.clip(transformed / state['clip_value'], 0.0, 1.0)
    h = (amount <= state['micro_max']).astype(float)
    u = 1.0 + state['beta'] * g + state['eta'] * h
    weight = np.ones(len(y), dtype=float)
    pos = y == 1
    weight[pos] = (state['kappa'] * state['class_ratio']
                   * u[pos] / state['u_bar_pos'])
    if not np.isfinite(weight).all() or (weight <= 0).any():
        raise ValueError('出现非有限或非正样本权重')
    return weight


def cross_val_transform_oof(model_name, data, feature_cols, beta, eta, kappa,
                            amount_transform, clip_quantile,
                            random_state=CV_RANDOM_STATE):
    X, y = data[feature_cols], data['Class'].astype(int)
    amount = data['Amount'].astype(float)
    oof = np.full(len(data), np.nan, dtype=float)
    fold_ap = []
    for fold, (tr, va) in enumerate(iter_purged_cv_folds(data), start=1):
        fit_mask, es_mask = temporal_es_masks(y.iloc[tr])
        fit_idx, es_idx = tr[fit_mask], tr[es_mask]
        state = fit_transform_weight_state(
            amount.iloc[fit_idx], y.iloc[fit_idx], beta, eta, kappa,
            amount_transform, clip_quantile)
        sw_fit = transform_sensitivity_weight(
            amount.iloc[fit_idx], y.iloc[fit_idx], state)
        clf = make_classifier(
            model_name, y.iloc[fit_idx], random_state + fold,
            weight_scheme='no_weight')
        fit_classifier(
            clf, model_name, X.iloc[fit_idx], y.iloc[fit_idx],
            X.iloc[es_idx], y.iloc[es_idx], sample_weight=sw_fit)
        p = clf.predict_proba(X.iloc[va])[:, 1]
        oof[va] = p
        fold_ap.append(float(average_precision_score(y.iloc[va], p)))
        print(f'  {model_name} {amount_transform}/q{clip_quantile:.2f} '
              f'fold {fold}/{CV_N_SPLITS} 完成')
    return oof, fold_ap

# %% [markdown]
# ## 12. 第一阶段：单种子初筛
#
# 初筛只使用 BASE 特征与 seed=42。每个模型先由原始 BASE 在 calibration 上得到最佳 F1 告警率；中性 BASE、原 `log+q95` 损失和全部 18 个候选共享该告警率，因此 Top-K 工作量相同。
#
# 最终候选严格按 calibration 指标选择。evaluation 列可以保存供最终验收，但不会进入 `select_transform_candidate()`。

# %%
# §12 prep：敏感性 OOF 缓存、三对照与 18 候选
def transform_cache_key(model_name, feature_group, amount_transform,
                        clip_quantile, beta, eta, kappa, seed):
    raw = (f'transform-v1|{model_name}|{feature_group}|{amount_transform}|'
           f'{clip_quantile:.4f}|{beta:.8g}|{eta:.8g}|{kappa:.8g}|{seed}')
    return hashlib.sha1(raw.encode('utf-8')).hexdigest()[:18]


def get_transform_oof(model_name, data, feature_cols, feature_group,
                      amount_transform, clip_quantile, beta, eta, kappa,
                      seed=CV_RANDOM_STATE):
    key = transform_cache_key(
        model_name, feature_group, amount_transform, clip_quantile,
        beta, eta, kappa, seed)
    path = TRANSFORM_OOF_CACHE / f'{model_name}_{feature_group}_{key}.npz'
    if path.is_file() and not FORCE_RERUN:
        saved = np.load(path, allow_pickle=False)
        return saved['oof'], saved['fold_ap'].tolist()
    oof, fold_ap = cross_val_transform_oof(
        model_name, data, feature_cols, beta, eta, kappa,
        amount_transform, clip_quantile, seed)
    np.savez_compressed(path, oof=oof, fold_ap=np.asarray(fold_ap, dtype=float))
    return oof, fold_ap


def original_seed_oof(model_name, data, features, feature_group,
                      loss_kind, beta, eta, kappa, seed):
    if seed == CV_RANDOM_STATE:
        return get_oof(model_name, data, features, feature_group,
                       loss_kind, beta, eta, kappa)
    key = cache_key(model_name, feature_group, loss_kind, beta, eta, kappa)
    path = OOF_CACHE_DIR / f'seed{seed}_{model_name}_{feature_group}_{loss_kind}_{key}.npz'
    if path.is_file() and not FORCE_RERUN:
        saved = np.load(path, allow_pickle=False)
        return saved['oof'], saved['fold_ap'].tolist()
    if loss_kind == 'builtin':
        oof, fold_ap = cross_val_builtin_oof(
            model_name, data, features, random_state=seed)
    else:
        oof, fold_ap, _ = cross_val_weighted_oof(
            model_name, data, features, beta, eta, kappa,
            random_state=seed)
    np.savez_compressed(path, oof=oof, fold_ap=np.asarray(fold_ap))
    return oof, fold_ap


def _transform_result_row(data, oof, fold_ap, alert_rate, **meta):
    row = evaluate_oof_business(data, oof, fold_ap, alert_rate=alert_rate)
    row.update(meta)
    return row


def run_transform_screen(data):
    original = get_original_selected_params()
    rows = []
    for model_name in MODELS:
        p0 = original[model_name]
        anchor_oof, anchor_ap = original_seed_oof(
            model_name, data, BASE_FEATURES, 'BASE', 'builtin', 0, 0, 1, 42)
        anchor = evaluate_oof_business(data, anchor_oof, anchor_ap)
        alert_rate = anchor['alert_rate']
        rows.append(anchor | {
            'feature_group': 'BASE', 'model': model_name,
            'experiment': 'screen_builtin', 'loss_kind': 'builtin',
            'amount_transform': 'none', 'clip_quantile': np.nan,
            'beta': 0.0, 'eta': 0.0, 'kappa': 1.0, 'beta_multiplier': np.nan})

        controls = [
            ('screen_neutral', 0.0, 0.0, 1.0),
            ('screen_original', float(p0['beta']), float(p0['eta']), float(p0['kappa'])),
        ]
        for experiment, beta, eta, kappa in controls:
            oof, fold_ap = original_seed_oof(
                model_name, data, BASE_FEATURES, 'BASE', 'amount_aware',
                beta, eta, kappa, 42)
            rows.append(_transform_result_row(
                data, oof, fold_ap, alert_rate,
                feature_group='BASE', model=model_name, experiment=experiment,
                loss_kind='amount_aware', amount_transform='log',
                clip_quantile=0.95, beta=beta, eta=eta, kappa=kappa,
                beta_multiplier=(0.0 if experiment == 'screen_neutral' else 1.0)))

        for amount_transform in AMOUNT_TRANSFORMS:
            for clip_quantile in CLIP_QUANTILES:
                for multiplier in BETA_MULTIPLIERS:
                    beta = float(p0['beta']) * multiplier
                    oof, fold_ap = get_transform_oof(
                        model_name, data, BASE_FEATURES, 'BASE', amount_transform,
                        clip_quantile, beta, float(p0['eta']), float(p0['kappa']), 42)
                    rows.append(_transform_result_row(
                        data, oof, fold_ap, alert_rate,
                        feature_group='BASE', model=model_name,
                        experiment='transform_candidate', loss_kind='amount_aware',
                        amount_transform=amount_transform,
                        clip_quantile=float(clip_quantile), beta=beta,
                        eta=float(p0['eta']), kappa=float(p0['kappa']),
                        beta_multiplier=float(multiplier)))
                    pd.DataFrame(rows).to_csv(
                        OUT_TRANSFORM_SCREEN / 'screen_checkpoint.csv', index=False)
    result = pd.DataFrame(rows)
    result.to_csv(OUT_TRANSFORM_SCREEN / 'screen_results.csv', index=False)
    return result


def select_transform_candidate(screen_results):
    selected = {}
    candidates = screen_results[
        screen_results['experiment'] == 'transform_candidate'].copy()
    candidates['_transform_preference'] = candidates['amount_transform'].map({'log': 0, 'sqrt': 1})
    for model_name in MODELS:
        part = candidates[candidates['model'] == model_name].sort_values(
            ['AmountRecall_cal_atK', 'MissedAmount_cal_atK',
             'MicroRecall_cal_atK', 'AUC-PR_cal', 'beta_multiplier',
             'clip_quantile', '_transform_preference'],
            ascending=[False, True, False, False, True, True, True])
        best = part.iloc[0]
        selected[model_name] = {
            'amount_transform': str(best['amount_transform']),
            'clip_quantile': float(best['clip_quantile']),
            'beta': float(best['beta']), 'eta': float(best['eta']),
            'kappa': float(best['kappa']),
            'beta_multiplier': float(best['beta_multiplier']),
        }
    return selected

# %%
# §12 exec：初筛默认关闭，可读取正式缓存
screen_path = OUT_TRANSFORM_SCREEN / 'screen_results.csv'
selected_path = OUT_TRANSFORM_SCREEN / 'selected_transform_params.json'
if RUN_TRANSFORM_SCREEN:
    transform_screen_results = run_transform_screen(df_all)
    SELECTED_TRANSFORM_PARAMS = select_transform_candidate(transform_screen_results)
    selected_path.write_text(
        json.dumps(SELECTED_TRANSFORM_PARAMS, ensure_ascii=False, indent=2),
        encoding='utf-8')
else:
    transform_screen_results = (pd.read_csv(screen_path)
                                if screen_path.is_file() else pd.DataFrame())
    SELECTED_TRANSFORM_PARAMS = (json.loads(selected_path.read_text(encoding='utf-8'))
                                 if selected_path.is_file() else {})
    print('RUN_TRANSFORM_SCREEN=False；已有初筛行数:', len(transform_screen_results))

if not transform_screen_results.empty:
    screen_show = transform_screen_results.copy()
    screen_show['experiment'] = screen_show['experiment'].replace({
        'screen_builtin': '原始 BASE', 'screen_neutral': '中性 BASE',
        'screen_original': '原 log+q95', 'transform_candidate': '变换候选'})
    display(screen_show[[
        'model', 'experiment', 'amount_transform', 'clip_quantile',
        'beta_multiplier', 'beta', 'AmountRecall_cal_atK',
        'MissedAmount_cal_atK', 'MicroRecall_cal_atK', 'AUC-PR_cal',
    ]].sort_values(['model', 'experiment', 'AmountRecall_cal_atK'],
                   ascending=[True, True, False]).round(5))
    print(json.dumps(SELECTED_TRANSFORM_PARAMS, ensure_ascii=False, indent=2))
# Out:
# RUN_TRANSFORM_SCREEN=False；已有初筛行数: 42
#        model experiment amount_transform  clip_quantile  beta_multiplier     beta  AmountRecall_cal_atK  MissedAmount_cal_atK  MicroRecall_cal_atK  \
# 1   LightGBM    中性 BASE              log           0.95              0.0  0.00000               0.76971               2783.79              0.78125
# 2   LightGBM  原 log+q95              log           0.95              1.0  0.34850               0.79154               2519.92              0.78125
# 0   LightGBM    原始 BASE             none            NaN              NaN  0.00000               0.76980               2782.79              0.81250
# 3   LightGBM       变换候选              log           0.90              0.5  0.17425               0.79154               2519.92              0.78125
# 4   LightGBM       变换候选              log           0.90              1.0  0.34850               0.79154               2519.92              0.78125
# 7   LightGBM       变换候选              log           0.95              1.0  0.34850               0.79154               2519.92              0.78125
# 16  LightGBM       变换候选             sqrt           0.95              1.0  0.34850               0.79154               2519.92              0.78125
# 6   LightGBM       变换候选              log           0.95              0.5  0.17425               0.79146               2520.92              0.75000
# 10  LightGBM       变换候选              log           0.99              1.0  0.34850               0.79146               2520.92              0.75000
# 11  LightGBM       变换候选              log           0.99              2.0  0.69700               0.79146               2520.92              0.75000
# 12  LightGBM       变换候选             sqrt           0.90              0.5  0.17425               0.79146               2520.92              0.75000
# 13  LightGBM       变换候选             sqrt           0.90              1.0  0.34850               0.79146               2520.92              0.75000
# 14  LightGBM       变换候选             sqrt           0.90              2.0  0.69700               0.79146               2520.92              0.75000
# 17  LightGBM       变换候选             sqrt           0.95              2.0  0.69700               0.79146               2520.92              0.75000
# 8   LightGBM       变换候选              log           0.95              2.0  0.69700               0.78997               2538.96              0.78125
# 9   LightGBM       变换候选              log           0.99              0.5  0.17425               0.78997               2538.96              0.78125
# 18  LightGBM       变换候选             sqrt           0.99              0.5  0.17425               0.78997               2538.96              0.78125
# 19  LightGBM       变换候选             sqrt           0.99              1.0  0.34850               0.78997               2538.96              0.78125
# 5   LightGBM       变换候选              log           0.90              2.0  0.69700               0.76988               2781.79              0.78125
# 15  LightGBM       变换候选             sqrt           0.95              0.5  0.17425               0.76988               2781.79              0.78125
# 20  LightGBM       变换候选             sqrt           0.99              2.0  0.69700               0.76980               2782.79              0.75000
# 22   XGBoost    中性 BASE              log           0.95              0.0  0.00000               0.73619               3188.99              0.81250
# 23   XGBoost  原 log+q95              log           0.95              1.0  4.24844               0.76260               2869.79              0.84375
# 21   XGBoost    原始 BASE             none            NaN              NaN  0.00000               0.76260               2869.79              0.84375
# 26   XGBoost       变换候选              log           0.90              2.0  8.49687               0.76260               2869.79              0.84375
# 28   XGBoost       变换候选              log           0.95              1.0  4.24844               0.76260               2869.79              0.84375
# 30   XGBoost       变换候选              log           0.99              0.5  2.12422               0.76260               2869.79              0.84375
# 34   XGBoost       变换候选             sqrt           0.90              1.0  4.24844               0.76260               2869.79              0.84375
# 35   XGBoost       变换候选             sqrt           0.90              2.0  8.49687               0.76260               2869.79              0.84375
# 36   XGBoost       变换候选             sqrt           0.95              0.5  2.12422               0.76260               2869.79              0.84375
# 37   XGBoost       变换候选             sqrt           0.95              1.0  4.24844               0.76260               2869.79              0.84375
# 38   XGBoost       变换候选             sqrt           0.95              2.0  8.49687               0.76260               2869.79              0.84375
# 39   XGBoost       变换候选             sqrt           0.99              0.5  2.12422               0.76260               2869.79              0.81250
# 40   XGBoost       变换候选             sqrt           0.99              1.0  4.24844               0.76260               2869.79              0.84375
# 41   XGBoost       变换候选             sqrt           0.99              2.0  8.49687               0.76260               2869.79              0.84375
# 31   XGBoost       变换候选              log           0.99              1.0  4.24844               0.76252               2870.79              0.81250
# 32   XGBoost       变换候选              log           0.99              2.0  8.49687               0.76252               2870.79              0.81250
# 29   XGBoost       变换候选              log           0.95              2.0  8.49687               0.76243               2871.79              0.78125
# 24   XGBoost       变换候选              log           0.90              0.5  2.12422               0.73619               3188.99              0.84375
# 27   XGBoost       变换候选              log           0.95              0.5  2.12422               0.73619               3188.99              0.84375
# 33   XGBoost       变换候选             sqrt           0.90              0.5  2.12422               0.73619               3188.99              0.84375
# 25   XGBoost       变换候选              log           0.90              1.0  4.24844               0.73611               3189.99              0.81250
#
#     AUC-PR_cal
# 1      0.76649
# 2      0.76940
# 0      0.77364
# 3      0.76624
# 4      0.76386
# 7      0.76940
# 16     0.76510
# 6      0.76565
# 10     0.76539
# 11     0.76611
# 12     0.76439
# 13     0.76378
# 14     0.76407
# 17     0.76633
# 8      0.76522
# 9      0.76585
# 18     0.76261
# 19     0.76280
# 5      0.76834
# 15     0.76821
# 20     0.76294
# 22     0.75539
# 23     0.76030
# 21     0.75594
# 26     0.76258
# 28     0.76030
# 30     0.75258
# 34     0.75682
# 35     0.75976
# 36     0.75428
# 37     0.75712
# 38     0.75936
# 39     0.75058
# 40     0.75422
# 41     0.75866
# 31     0.76177
# 32     0.75389
# 29     0.75204
# 24     0.75453
# 27     0.75716
# 33     0.75728
# 25     0.75716
# {
#   "LightGBM": {
#     "amount_transform": "log",
#     "clip_quantile": 0.95,
#     "beta": 0.3485016730091967,
#     "eta": 5.197056874649611,
#     "kappa": 1.1213380140918507,
#     "beta_multiplier": 1.0
#   },
#   "XGBoost": {
#     "amount_transform": "log",
#     "clip_quantile": 0.9,
#     "beta": 8.496870933552547,
#     "eta": 0.1235069657748146,
#     "kappa": 1.5638918225943934,
#     "beta_multiplier": 2.0
#   }
# }
